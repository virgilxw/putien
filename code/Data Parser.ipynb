# %% [markdown]
# # Text parser for volume two
#
# This jupyter notebook file houses all of the code used during the porject.
#
# ## Do not run any of the scripts as doing so will override most of the output data which has been sanitised manually. Only use it as a reference, and write new code.

# %%
# DO NOT USE

# To remove frontmatter and backmatter from the .txt transcriptions of the PDF file

import os
with open("./input/raw.txt", "r") as infile:
    data = infile.readlines()
    
    # Usable Parts of Section Two
    with open("input/Southern.txt", 'w') as outfile:
        outfile.writelines(data[3074:18607])
        
    # Usable Parts of Section Three
    with open("Northern.txt", 'w') as outfile:
        outfile.writelines(data[18611:39874])
        
    # Usable Parts of Section Four
    with open("Jiuliyang.txt", 'w') as outfile:
        outfile.writelines(data[39727:43643])

# %%
# DO NOT USE
# Remove watermarks

import re


def refine(file):
    # Function to process raw data for future further operation
    
    buffer = None
    
    with open(file, "r+") as f:
        buffer = f.read()
        f.seek(0)
        
        # Delete Watermarks
        buffer = re.sub("Kenneth Dean and Zhenman ZHENG - 978-90-47-44017-8", "", buffer).rstrip()
        buffer = re.sub("Downloaded from Brill.com02/18/2020 04:31:15AM", "", buffer).rstrip()
        buffer = re.sub("via National University of Singapore - YNC Library", "", buffer).rstrip()
        
        # Delete Headers
        buffer = re.sub("the southern irrigated plain 南洋水利系统", "", buffer).rstrip()
        buffer = re.sub("the northern irrigated plain 北洋水利系统", "", buffer).rstrip()
        buffer = re.sub("the jiuliyang irrigated plain 九里洋水利系统", "", buffer).rstrip()
        buffer = re.sub("part (one|two|three|four|five)", "", buffer).rstrip()
        
        # Delete Page Numbers
        buffer = re.sub("\n[0-9]+\n", "", buffer).rstrip()
        buffer = re.sub("\f(.*?)\n", "", buffer).rstrip()
        buffer = re.sub("\n\n(A|V)[0-9]+\n\n\n", "", buffer).rstrip()
        
        # Delete blank lines
        buffer = re.sub("\n+", " ", buffer).rstrip()
        
        # Add line breaks at each new entry
        buffer = re.sub("((A|V)[0-9]{3})", "\n\g<1>", buffer)

        f.truncate()        
        f.write(buffer)

# %%
# DO NOT USE
# Remove watermarks

refine("Southern.txt")
refine("Northern.txt")
refine("Jiuliyang.txt")

# %%
# DO NOT USE
# Read god names and create JSON of them

import os, json

godsList= []

with open("input/list_of_gods.txt", 'r') as infile:
    data = infile.readlines()
    
    for line in data:
        EngText=" ".join(line.split()[:-1]).split("/")
        
        lineEntry = {
            "Name": EngText[0],
            "Name_zh": line.split()[-1]
        }
        
        if len(EngText) > 1:
            lineEntry["Aliases"] = EngText[1:]
        else:
            lineEntry["Aliases"] = []
        
        godsList.append(lineEntry)
        
    infile.close()

with open("./output/god_names.json", "w") as outfile:
    json.dump(godsList, outfile, ensure_ascii=False)
    outfile.close()

# %%
# DO NOT USE
# Load and map villages into Javascript objects for future use

import re, os, json

village_index = []

with open("./input/contents.txt") as infile:
    for line in infile:
        buffer = re.split("(V[0-9]{3})", line)      
        entry = {
            "UID_A": buffer[0][0:4],
            "Name": " ".join(buffer[0].split(" ")[1:-2]),
            "Name_zh": buffer[0].split(" ")[-2]
        }

        runs = int((len(buffer)-1)/2 + 1)
        villageList=[]

        for i in range(1,runs):
            village_entry = {
                "UID_V": buffer[i*2-1],
                "Name": buffer[i*2].split(" ")[1],
                "Name_zh": buffer[i*2].split(" ")[2]
            }
            villageList.append(village_entry)

        entry["Num_Villages"] = len(villageList)
        entry["Villages"] = villageList

        village_index.append(entry)

with open("./output/village_index.json", "w") as outfile:
    json.dump(village_index, outfile, ensure_ascii=False)
    outfile.close()

infile.close()
    
#search function
def whatAlliance(searchterm):
    for alliance in village_index:
        for village in alliance["Villages"]:
            if village["UID_V"] == searchterm:
                return alliance
        
    return -1

# %%
# DO NOT USE
# Load surname mapping functions

with open('./input/Surname_Groups.json', "r") as surnameFile:
    surnameGroups = json.load(surnameFile)
surnameFile.close()

#search function
def whatSurnames(searchterm):
    for village in surnameGroups:
        if village["UID"] == searchterm:
            return village
    return -1

# %%
# DO NOT USE
# Text Parsing to create a "Village_Master" master object from which data can be accessed. 
 
import json, regex

def createVillageFiles(path, irrNetwork):
    
    with open(path) as infile:
        for line in infile:
            if line[0] == "V":
                uid = line[0:4]                
                buffer1 = line.split(" ", 3)
                buffer2 = buffer1[3].partition("2. Surname groups")
                buffer3 = buffer2[2].partition("3. Village temples")
                buffer4 = buffer3[2].partition("4. Rituals")
                buffer5 = buffer4[2].partition("Birthday celebrations of the gods")
                buffer6 = buffer5[2].partition("5. Ritual Groups")
                
                if buffer6 is None:
                    buffer6 = ""
            
                # Search for Alliance details
                allianceDetails = whatAlliance(uid)
                
                temples = regex.split("(?:^|\.\s)\d+\)(?=\s[A-Z])", buffer4[0])
            
                entry = {
                    "UID": buffer1[0],
                    "Name": buffer1[1],
                    "Name_zh": buffer1[2],
                    "Alliance": allianceDetails["Name"],
                    "Alliance_UID": allianceDetails["UID_A"],
                    "Alliance_zh": allianceDetails["Name_zh"],
                    "Irrigation_Region": irrNetwork,
                    "Raw_Text": {                        
                        "Village_Settlement": buffer2[0][22:],
                        "Surname_Groups": buffer3[0][1:],
                        "Village_Temples": buffer4[0][1:],
                        "Rituals": {
                            "Yuanxiao processions": buffer5[0][23:],
                            "Birthday celebrations of the gods": buffer5[2][1:].strip(),
                            "Ritual Groups": buffer6[2]
                        }
                    }
                }
                
                # Add administrative village if applicable
                admin_village = re.search("\w* Administrative Village\s([^\.\s]+)", entry["Raw_Text"]["Village_Settlement"])
                if admin_village != None:
                    split_words = admin_village.group(0).split(" ")
                    entry["Raw_Text"]["Administrative_Village"] = " ".join(split_words[:-1])
                    entry["Raw_Text"]["Administrative_Village_zh"] = "".join(split_words[-1])                    
                else:
                    entry["Administrative_Village"] = "-1"
                    entry["Administrative_Village_zh"] = "-1"
                    
               # Find Population
                pop = re.search("[0-9,]*(?=\speople|\sresidents|\sinhabitants)", entry["Raw_Text"]["Village_Settlement"])
                
                if pop == None:
                    pop = re.search("[\w\s]*(people|residents|inhabitants|population)[\w\s]*", entry["Raw_Text"]["Village_Settlement"])
                    
                    if pop == None:
                        entry["Population"] = -1
                    else:                    
                        pop = re.search("[0-9,]*", pop.group(0))
                    
                        if pop == None:
                            entry["Population"] = -1
                        else:
                            entry["Population"] = pop.group(0)
                else:
                    entry["Population"] = pop.group(0)
                
                # Number of temples
                # Main Gods Worshipped
                Main_Gods = []
                num_temple = 0
                
                    for god in godsList:
                        if god["Name"] in templedata.group(0):
                            if not god["Name"] in Main_Gods:
                                Main_Gods.append(god["Name"])
                        else:
                            for aliases in god["Aliases"]:
                                if aliases in templedata.group(0):
                                    if not god["Name"] in Main_Gods:
                                        Main_Gods.append(god["Name"])
                                        
                    num_temple = num_temple + 1
                
                entry["Num_Temples"] = str(num_temple)
                entry["Main_Gods"] = Main_Gods
                entry["Num_Main_Gods"] = str(len(Main_Gods))
                
                # Secondary Gods Worshipped
                Sec_Gods = []
                for templedata in re.finditer("\.*(secondary)([^.]+)\.", entry["Raw_Text"]["Village_Temples"], flags=re.IGNORECASE):
                    # print(uid, templedata)
                    for god in godsList:
                        if god["Name"] in templedata.group(0):
                            if not god["Name"] in Sec_Gods:
                                Sec_Gods.append(god["Name"])
                        else:
                            for aliases in god["Aliases"]:
                                if aliases in templedata.group(0):
                                    if not god["Name"] in Sec_Gods:
                                        Sec_Gods.append(god["Name"])
                
                entry["Secondary_Gods"] = Sec_Gods
                entry["Num_Secondary_Gods"] = str(len(Sec_Gods))
                
                villages.append(entry) 
                
    infile.close()
    
    # dump to file
    with open("./output/village_master.json", "w") as outfile:
        json.dump(villages, outfile, ensure_ascii=False)
        outfile.close()
        
    return villages

# %%
# DO NOT USE
#

villages = []

overview = createVillageFiles("./input/1-100.txt", "Southern")
overview = createVillageFiles("./input/101-200.txt", "Southern")
overview = createVillageFiles("./input/201-297.txt", "Southern")
overview = createVillageFiles("./input/298-400.txt", "Northern")
overview = createVillageFiles("./input/401-500.txt", "Northern")
overview = createVillageFiles("./input/501-600.txt", "Northern")
overview = createVillageFiles("./input/601-659.txt", "Northern")
overview = createVillageFiles("./input/jiuliyang.txt", "Jiuliyang")
print("Completed")
# Out:
# Completed

# %%
# DO NOT USE
# Create summary.csv

import json, csv

with open('./output/village_master.json') as infile:
    
    indata = json.load(infile)
    
    # General data including 1) UID, 2) Name, 3) Name_zh, 4) Alliance, 5) Alliance_UID, 6) Alliance_zh, 7) Irrigation_Region
    keysToExtract = ["UID", "Name", "Name_zh", "Alliance", "Alliance_UID", "Alliance_zh", "Irrigation_Region"]
    genDataBuffer = []
        
    for entry in indata:
        
        outEntry = {}
        
        for var in entry:
            if var in keysToExtract:
                outEntry[var] = entry[var]
                
        genDataBuffer.append(outEntry)
        
    with open('./output/summary.csv', 'w') as output_file:
        dict_writer = csv.DictWriter(output_file, fieldnames=keysToExtract, delimiter=',')
        dict_writer.writeheader()
        dict_writer.writerows(genDataBuffer)

# %%
# DO NOT USE
# Parse village data to a CSV which can be imported into PostGIS

import json, csv

with open('./output/village_master.json') as infile:
    
    indata = json.load(infile)
    
    villages_out= []
    
    for entry in indata:
        
        entry = {
            "UID_V": entry["UID"],
            "name": entry["Name"],
            "name_zh": entry["Name_zh"],
            "irrigation_region": entry["Irrigation_Region"],
            "population": entry["Population"],
        }
        
        villages_out.append(entry)
    
    with open("./output/Villages.csv", "w") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=villages_out[0].keys())
        writer.writeheader()
        writer.writerows(villages_out)

# %%
# DO NOT USE
# Parse village data to a file with the Raw Text of each section

import json, csv

with open('./output/village_master.json') as infile:
    indata = json.load(infile)
    
    villages_out = []
    
    for in_entry in indata:
        
        out_entry = {
            "UID": in_entry["UID"],
            "Name": in_entry["Name"],
            "Name_zh": in_entry["Name_zh"],
            "Village_Settlement": in_entry["Raw_Text"]["Village_Settlement"],
            "Surname_Groups": in_entry["Raw_Text"]["Surname_Groups"],
            "Village_Temples": in_entry["Raw_Text"]["Village_Temples"],
            "Rituals_Yuanxiao_Processions": in_entry["Raw_Text"]["Rituals"]["Yuanxiao processions"],
            "Rituals_Birthday_Celebration_of_gods": in_entry["Raw_Text"]["Rituals"]["Birthday celebrations of the gods"],
            "Rituals_Ritual_Groups": in_entry["Raw_Text"]["Rituals"]["Ritual Groups"]
        }
        
        villages_out.append(out_entry)
    
    with open("./output/Raw_Data.csv", "w") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=villages_out[0].keys(),quoting=csv.QUOTE_ALL, escapechar='\\')
        writer.writeheader()
        writer.writerows(villages_out)    
        
    with open("./output/Raw_Data.json", "w") as outfile:
        json.dump(villages_out, outfile)

# %%
# DO NOT USE
# Parse village data to a CSV which can be imported into PostGIS

import json, csv

with open('./output/god_names.json') as infile:
    indata = json.load(infile)
    
    data_out = []
    
    for in_entry in indata:
        
        alias_string = "{" + ', '.join(in_entry["Aliases"]) + "}"
        
        print(alias_string)
        
        out_entry = {
            "God_Name": in_entry["Name"],
            "God_Name_zh": in_entry["Name_zh"],
            "Aliases": alias_string
        }
        
        print(out_entry)
        
        data_out.append(out_entry)
    
    with open("./output/God_Aliases.csv", "w") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=data_out[0].keys(),quoting=csv.QUOTE_ALL, escapechar='\\')
        writer.writeheader()
        writer.writerows(data_out)
# Out:
# {}
# {'God_Name': '18 luo han', 'God_Name_zh': '18罗汉', 'Aliases': '{}'}
# {Asi}
# {'God_Name': 'Asan', 'God_Name_zh': '阿三阿四', 'Aliases': '{Asi}'}
# {}
# {'God_Name': 'Aye gong', 'God_Name_zh': '阿爷公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Anling shenggong', 'God_Name_zh': '安灵圣公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Anshan shengwang', 'God_Name_zh': '安善圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ansheng lingfei', 'God_Name_zh': '安圣灵妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Aotou ma', 'God_Name_zh': '鳌头妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baban', 'God_Name_zh': '八班', 'Aliases': '{}'}
# {}
# {'God_Name': 'Babaoye', 'God_Name_zh': '八宝爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Bajiang', 'God_Name_zh': '八将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baxian', 'God_Name_zh': '八仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Bai daren', 'God_Name_zh': '白大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baifu daren', 'God_Name_zh': '白府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baigong daren', 'God_Name_zh': '白公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baihu jiangjun', 'God_Name_zh': '白虎将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baima jiangjun', 'God_Name_zh': '白马将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baima shenghou', 'God_Name_zh': '白马圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baima xianggong', 'God_Name_zh': '白马相公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baima yuanshuai', 'God_Name_zh': '白马元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baiya jiangjun', 'God_Name_zh': '白牙将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baiya zhongjun', 'God_Name_zh': '白牙中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Banshan daxian', 'God_Name_zh': '半山大仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baogong yuanshuai', 'God_Name_zh': '鲍公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baoling zhongjun', 'God_Name_zh': '保令中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baosheng dadi', 'God_Name_zh': '保生大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Baosong furen', 'God_Name_zh': '抱送夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Beidou shengwang', 'God_Name_zh': '北斗圣王(许远)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Beidou xingjun', 'God_Name_zh': '北斗星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Beidou zhongtian dasheng', 'God_Name_zh': '北斗中天大圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Beishan dawang', 'God_Name_zh': '北山大王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Beiyue Cao jiangjun', 'God_Name_zh': '北岳曹将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Bingling gong', 'God_Name_zh': '炳灵公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Boye', 'God_Name_zh': '伯爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Cai daren', 'God_Name_zh': '蔡大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Caigong yuanshuai', 'God_Name_zh': '蔡公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Cai zhongjun', 'God_Name_zh': '蔡中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Cao jiangjun', 'God_Name_zh': '曹将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen dajiangjun', 'God_Name_zh': '陈大将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen dashi', 'God_Name_zh': '陈大师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chenfu daren', 'God_Name_zh': '陈府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chengong sheren', 'God_Name_zh': '陈公舍人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chengong shenghou', 'God_Name_zh': '陈公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chengong taishi', 'God_Name_zh': '陈公太师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen jiangjun', 'God_Name_zh': '陈将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen Jinggu', 'God_Name_zh': '陈靖姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chenma', 'God_Name_zh': '陈妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chensheng faye', 'God_Name_zh': '陈圣法爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chensheng hufa', 'God_Name_zh': '陈圣护法', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chenshi zhenren', 'God_Name_zh': '陈氏真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen taiwei', 'God_Name_zh': '陈太尉', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen Wenlong', 'God_Name_zh': '陈文龙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen xiannu', 'God_Name_zh': '陈仙女', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen Zhida', 'God_Name_zh': '陈智达', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chen zongjun', 'God_Name_zh': '陈中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chenghuang dashen', 'God_Name_zh': '城隍大神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chifeng shengwang', 'God_Name_zh': '敕封圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chima jiangjun', 'God_Name_zh': '赤马将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Chou Liang dawang', 'God_Name_zh': '臭梁大王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Cigan niangniang', 'God_Name_zh': '慈感娘娘', 'Aliases': '{}'}
# {Cigan renhui xianfei}
# {'God_Name': 'Cigan xianfei', 'God_Name_zh': '慈感仙妃', 'Aliases': '{Cigan renhui xianfei}'}
# {}
# {'God_Name': 'Ciji zhenjun', 'God_Name_zh': '慈济真君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Congzi', 'God_Name_zh': '囱子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Cuifu dama', 'God_Name_zh': '鲁府大妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Cuifu daren', 'God_Name_zh': '崔府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Da diye', 'God_Name_zh': '大帝爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dafa tianshi', 'God_Name_zh': '大法天师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dage', 'God_Name_zh': '大哥', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dama', 'God_Name_zh': '大妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Damou zushi', 'God_Name_zh': '达摩祖师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Da qing', 'God_Name_zh': '大青', 'Aliases': '{}'}
# {}
# {'God_Name': 'Da qing', 'God_Name_zh': '大青', 'Aliases': '{}'}
# {}
# {'God_Name': 'Daren', 'God_Name_zh': '大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Daxiong', 'God_Name_zh': '大兄', 'Aliases': '{}'}
# {}
# {'God_Name': 'Daye', 'God_Name_zh': '大爷', 'Aliases': '{}'}
# {Da ye, Er ye}
# {'God_Name': 'Da ye, Er ye', 'God_Name_zh': '大爷/二爷', 'Aliases': '{Da ye, Er ye}'}
# {Deng zhongjun, Wang zhongjun, Shi Zhongjun}
# {'God_Name': 'Deng, Wang, Shi zhongjun', 'God_Name_zh': '邓,王,施中军', 'Aliases': '{Deng zhongjun, Wang zhongjun, Shi Zhongjun}'}
# {}
# {'God_Name': 'Diguan dadi', 'God_Name_zh': '地官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dikui', 'God_Name_zh': '地魁', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dizang pusa', 'God_Name_zh': '地藏菩萨', 'Aliases': '{}'}
# {Dizangwang}
# {'God_Name': 'Dizang wang', 'God_Name_zh': '地藏王', 'Aliases': '{Dizangwang}'}
# {}
# {'God_Name': 'Dian daren', 'God_Name_zh': '电大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dianmu', 'God_Name_zh': '电母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ding yuanshuai', 'God_Name_zh': '丁元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dong eryuanshui', 'God_Name_zh': '董二元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dongfu xiansheng', 'God_Name_zh': '东阜先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dongxi shizhe', 'God_Name_zh': '东西使者', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dongyue dadi', 'God_Name_zh': '东岳大帝', 'Aliases': '{}'}
# {Dongyue zhusheng}
# {'God_Name': 'Dongyue zhusheng shangdi', 'God_Name_zh': '东岳注生上帝', 'Aliases': '{Dongyue zhusheng}'}
# {}
# {'God_Name': 'Dong Zhian', 'God_Name_zh': '董直庵', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dong, Ge, Zhou sanjiangjun', 'God_Name_zh': '董,葛,周三将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ducha dashen', 'God_Name_zh': '都察大神', 'Aliases': '{}'}
# {Zhenggong dudu, Qigong dudu, Qi Jiguang, Qidudu}
# {'God_Name': 'Dudu ye', 'God_Name_zh': '都督爷/郑公都督/戚公都督/戚继光都督', 'Aliases': '{Zhenggong dudu, Qigong dudu, Qi Jiguang, Qidudu}'}
# {}
# {'God_Name': 'Dufei niangniang', 'God_Name_zh': '都妃娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Duguan pusa', 'God_Name_zh': '都管菩萨', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dutian yuanshuai', 'God_Name_zh': '都天元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dutong', 'God_Name_zh': '都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dutong shenghou', 'God_Name_zh': '都统圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dutong yuanshuai', 'God_Name_zh': '都统元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Dutong zunwang', 'God_Name_zh': '都统尊王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Enzhu sangong', 'God_Name_zh': '恩主三公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Er daren', 'God_Name_zh': '二大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Er langshen', 'God_Name_zh': '二郎神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ershi', 'God_Name_zh': '二使', 'Aliases': '{}'}
# {}
# {'God_Name': 'Erwei jinren', 'God_Name_zh': '二位金人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Er xingjun', 'God_Name_zh': '二星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Erxiong', 'God_Name_zh': '二兄', 'Aliases': '{}'}
# {}
# {'God_Name': 'Erye', 'God_Name_zh': '二爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Faling zushi', 'God_Name_zh': '法灵祖师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Falu dutong', 'God_Name_zh': '法律都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fa zhongjun', 'God_Name_zh': '法中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fazhu niangniang', 'God_Name_zh': '法主娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fazhu xianfei', 'God_Name_zh': '法主仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fan erye', 'God_Name_zh': '范二爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fanxiang xianshi', 'God_Name_zh': '范相仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fanghuo dadi', 'God_Name_zh': '放火大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fengbo', 'God_Name_zh': '风伯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fengbo yushi', 'God_Name_zh': '风伯雨师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fenghuo ertong', 'God_Name_zh': '风火儿童', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fogong', 'God_Name_zh': '佛公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fozu', 'God_Name_zh': '佛祖', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fu daren', 'God_Name_zh': '傅大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fude zhengshen', 'God_Name_zh': '福德正神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fuhu', 'God_Name_zh': 'jiangjun', 'Aliases': '{}'}
# {Fuma shenghou}
# {'God_Name': 'Fuma shengjun', 'God_Name_zh': '福马圣君(福马圣侯)', 'Aliases': '{Fuma shenghou}'}
# {}
# {'God_Name': 'Furen', 'God_Name_zh': '夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Furenma', 'God_Name_zh': '夫人妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fushan shenghou', 'God_Name_zh': '孚善圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Fuyi xiansheng', 'God_Name_zh': '扶易先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gaogong', 'God_Name_zh': '高公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gaoshan shenghou', 'God_Name_zh': '高山圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gao yuanshuai', 'God_Name_zh': '高元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ge dajiang', 'God_Name_zh': '葛大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gong daren', 'God_Name_zh': '龚大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gongli lingwang', 'God_Name_zh': '功利灵王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gongying tongzi', 'God_Name_zh': '供应童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gongzheng mingwang', 'God_Name_zh': '恭正明王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Gouye', 'God_Name_zh': '狗爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guma', 'God_Name_zh': '姑妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guniang', 'God_Name_zh': '姑娘', 'Aliases': '{}'}
# {Guan diye}
# {'God_Name': 'Guangong', 'God_Name_zh': '关公/关帝爷', 'Aliases': '{Guan diye}'}
# {}
# {'God_Name': 'Guanhu jiangjun', 'God_Name_zh': '管虎将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guan Ping', 'God_Name_zh': '关平', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guansheng dijun', 'God_Name_zh': '关圣帝君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guansheng shenghou', 'God_Name_zh': '关圣圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guan Xing', 'God_Name_zh': '关兴', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guanyin', 'God_Name_zh': '观音', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guanyin dashi', 'God_Name_zh': '观音大士', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guangfu furen', 'God_Name_zh': '广福夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guanglie qiansui', 'God_Name_zh': '光烈千岁', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guangze zunwang', 'God_Name_zh': '广泽尊王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Guogong', 'God_Name_zh': '郭公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hangong', 'God_Name_zh': '韩公', 'Aliases': '{}'}
# {Haotian yuanshuai}
# {'God_Name': 'Haotian dizi', 'God_Name_zh': '昊天帝子', 'Aliases': '{Haotian yuanshuai}'}
# {}
# {'God_Name': 'He daren', 'God_Name_zh': '何大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heqing xingjun', 'God_Name_zh': '何清星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heshi jiuxian', 'God_Name_zh': '何氏九仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heshi xianshi', 'God_Name_zh': '何氏先师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heibai jiang', 'God_Name_zh': '黑白将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hei daren', 'God_Name_zh': '黑大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heigong daren', 'God_Name_zh': '黑公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heihu dashen', 'God_Name_zh': '黑虎大神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Heihu jiangjun', 'God_Name_zh': '黑虎将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hong daren', 'God_Name_zh': '洪大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hong haier', 'God_Name_zh': '红孩儿', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hou daren', 'God_Name_zh': '侯大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hougong shenghou', 'God_Name_zh': '候公圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Houtu furen', 'God_Name_zh': '后土夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huaxiangu', 'God_Name_zh': '花仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huban dashen', 'God_Name_zh': '虎班大神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hufa jialan', 'God_Name_zh': '护法伽兰', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hufa longtian', 'God_Name_zh': '护法龙天', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hu guniang', 'God_Name_zh': '胡姑娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hushan dawang', 'God_Name_zh': '壶山大王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huye jiangjun', 'God_Name_zh': '虎爷将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Hu yuanshuai', 'God_Name_zh': '胡元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huaguang dadi', 'God_Name_zh': '华光大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huang daren', 'God_Name_zh': '黄大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huang Daxian', 'God_Name_zh': '黄大仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huang daye', 'God_Name_zh': '黄大爷', 'Aliases': '{}'}
# {Huangdu yuanshuai}
# {'God_Name': 'Huang duyuanshuai', 'God_Name_zh': '黄都元帅', 'Aliases': '{Huangdu yuanshuai}'}
# {}
# {'God_Name': 'Huangfu daren', 'God_Name_zh': '黄府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huanggong', 'God_Name_zh': '黄公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huanggong dashi', 'God_Name_zh': '黄公大使', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huanggong ershi', 'God_Name_zh': '黄公二使', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huanggong shenghou', 'God_Name_zh': '黄公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huanggong yuanshuai', 'God_Name_zh': '黄公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huanghei jiangjun', 'God_Name_zh': '黄黑将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huangheng dadi', 'God_Name_zh': '黄横大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huang jiangjun', 'God_Name_zh': '黄将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huangsheng faye', 'God_Name_zh': '黄圣法爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huangshi xianfei', 'God_Name_zh': '黄氏仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huangxuan yuanshuai', 'God_Name_zh': '黄玄元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huang Zhong', 'God_Name_zh': '黄忠', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huang Zong', 'God_Name_zh': '黄总', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huibai cishi', 'God_Name_zh': '慧白慈师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huiji shenghou', 'God_Name_zh': '惠济圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huilie shenghou', 'God_Name_zh': '慧烈圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huiqing xianshi', 'God_Name_zh': '惠庆先师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huiying shenghou', 'God_Name_zh': '惠应圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huo daren', 'God_Name_zh': '火大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huofeng shenghou', 'God_Name_zh': '火风圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Huoguan dadi', 'God_Name_zh': '火官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jixiang dajiang', 'God_Name_zh': '吉祥大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jixiang erjiang', 'God_Name_zh': '吉祥二将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jixianggong', 'God_Name_zh': '吉祥公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jixiang miaojiang', 'God_Name_zh': '吉祥妙将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jixiang yuanshuai', 'God_Name_zh': '吉祥元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jixing', 'God_Name_zh': '急性', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jialan', 'God_Name_zh': '伽蓝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jialan pusa', 'God_Name_zh': '伽蓝菩萨', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jialuo dasheng', 'God_Name_zh': '伽罗大圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiayou shenghou', 'God_Name_zh': '嘉佑圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jianyin tongzi', 'God_Name_zh': '剑印童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiang daren', 'God_Name_zh': '江大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiangding shengwang', 'God_Name_zh': '江定圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiangfu zhizun', 'God_Name_zh': '江府至尊', 'Aliases': '{}'}
# {Zhaoshun shengwang}
# {'God_Name': 'Jiang Guojiu', 'God_Name_zh': '江国舅(昭顺圣王)', 'Aliases': '{Zhaoshun shengwang}'}
# {}
# {'God_Name': 'Jiang Meifei', 'God_Name_zh': '江梅妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jinda jiangjun', 'God_Name_zh': '金大将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jin daren', 'God_Name_zh': '金大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jinfu daren', 'God_Name_zh': '金府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jinfu sheren', 'God_Name_zh': '金复舍人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jingang mingwang', 'God_Name_zh': '金刚明王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jingong daren', 'God_Name_zh': '金公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jingong shenghou', 'God_Name_zh': '金公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jin qiren', 'God_Name_zh': '金旗人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jinshi xiangu', 'God_Name_zh': '金氏仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jin Yu chilin', 'God_Name_zh': '金玉齿人(临)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jin zhongjun', 'God_Name_zh': '金中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jingbian dutong', 'God_Name_zh': '静边都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiucha dasheng', 'God_Name_zh': '纠察大圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiuhua xianshi', 'God_Name_zh': '九华仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiu shengmu', 'God_Name_zh': '九圣母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiushu zushi', 'God_Name_zh': '九树祖师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiutian shangdi', 'God_Name_zh': '九天上帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiutian wang dadi', 'God_Name_zh': '九天王大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jiuxian', 'God_Name_zh': '九仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Jungong dianshuai', 'God_Name_zh': '郡公殿帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kailu jiangjun', 'God_Name_zh': '开路将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kang dage', 'God_Name_zh': '康大哥', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kanggong shenghou', 'God_Name_zh': '康公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kanggong shengwang', 'God_Name_zh': '康公圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kanggong yuanshuai', 'God_Name_zh': '康公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kefu zhenren', 'God_Name_zh': '柯府真人', 'Aliases': '{}'}
# {Kong fu daren}
# {'God_Name': 'Kongfu daren', 'God_Name_zh': '孔府大人', 'Aliases': '{Kong fu daren}'}
# {}
# {'God_Name': 'Kongming Zhouwang', 'God_Name_zh': '孔明周王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kongzi', 'God_Name_zh': '孔子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kuidou xingjun', 'God_Name_zh': '魁斗星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Kuixing wu yuanshuai', 'God_Name_zh': '魁星武元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lanfu daren', 'God_Name_zh': '蓝府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Langong yuanshuai', 'God_Name_zh': '蓝公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Leibu xingun', 'God_Name_zh': '雷部星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Leigong', 'God_Name_zh': '雷公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Leigong leimu', 'God_Name_zh': '雷公雷母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Leisheng puhua tianzun', 'God_Name_zh': '雷声普化天尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lei Wanchun', 'God_Name_zh': '武按圣王(雷万春)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Leixian', 'God_Name_zh': 'shengjie', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li dajiangjun', 'God_Name_zh': '李大将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li dama', 'God_Name_zh': '李大妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li daren', 'God_Name_zh': '李大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li daye', 'God_Name_zh': '李大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lide shifu', 'God_Name_zh': '德理师傅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li erye', 'God_Name_zh': '李二爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lifu daren', 'God_Name_zh': '李府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ligong yuanshuai', 'God_Name_zh': '李公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ligong zhangzhe', 'God_Name_zh': '李公长者', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li', 'God_Name_zh': 'jiangjun', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liming dajiang', 'God_Name_zh': '李明大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li mingdeng', 'God_Name_zh': '李明灯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li sanfuren', 'God_Name_zh': '李三夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lishi niangniang', 'God_Name_zh': '李氏娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li Tieguai', 'God_Name_zh': '李铁拐', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li xianshi', 'God_Name_zh': '李先师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li Zhen', 'God_Name_zh': '黎畛', 'Aliases': '{}'}
# {}
# {'God_Name': 'Li zhenren', 'God_Name_zh': '李真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liang Puyao', 'God_Name_zh': '梁普耀', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lin daren', 'God_Name_zh': '林大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingong dutong', 'God_Name_zh': '林公都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingong shifu', 'God_Name_zh': '林公师傅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lin Longjiang', 'God_Name_zh': '林龙江', 'Aliases': '{}'}
# {}
# {'God_Name': 'Linshui furen', 'God_Name_zh': '临水夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lin Zhao’en', 'God_Name_zh': '林兆恩', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lin Zhenming', 'God_Name_zh': '林贞明', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingguan dadi', 'God_Name_zh': '灵官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ling jiangjun', 'God_Name_zh': '灵将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingshantan', 'God_Name_zh': '灵山坛', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ling shengwang', 'God_Name_zh': '灵圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingshi shengwang', 'God_Name_zh': '灵石圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingshun shengfei', 'God_Name_zh': '灵顺圣妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingtong tongzi', 'God_Name_zh': '赁通童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingtong Zhang sheren', 'God_Name_zh': '灵通张舍人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingya jiangjun', 'God_Name_zh': '灵牙将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingya zhongjun', 'God_Name_zh': '岭牙中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lingyou shengwang', 'God_Name_zh': '灵佑圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu dajiang', 'God_Name_zh': '六大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu daren', 'God_Name_zh': '刘大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu daye', 'God_Name_zh': '柳大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liuding shenjiang', 'God_Name_zh': '六丁神将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liudu tong', 'God_Name_zh': '柳都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu gong shenghou', 'God_Name_zh': '柳公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liugong taibao', 'God_Name_zh': '刘公太保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liugong yuanshuai', 'God_Name_zh': '刘公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liujia jiangjun', 'God_Name_zh': '六甲将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu jiangjun', 'God_Name_zh': '柳将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu Jin shenghou', 'God_Name_zh': '柳金圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liumihou', 'God_Name_zh': '六弥猴', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liushi niangniang', 'God_Name_zh': '刘氏娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu tai gong', 'God_Name_zh': '刘太公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu xiangu', 'God_Name_zh': '柳仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu xiansheng', 'God_Name_zh': '刘先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu xianshi', 'God_Name_zh': '刘仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu yuandajiang', 'God_Name_zh': '六员大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu yuanshuai', 'God_Name_zh': '刘元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Liu zhongjun', 'God_Name_zh': '刘中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Longnu', 'God_Name_zh': '龙女', 'Aliases': '{}'}
# {Sihai longwang}
# {'God_Name': 'Longwang', 'God_Name_zh': '龙王(四海龙王)', 'Aliases': '{Sihai longwang}'}
# {}
# {'God_Name': 'Luban xianshi', 'God_Name_zh': '鲁班仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lubu dashen', 'God_Name_zh': '鲁部大神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lubu furen', 'God_Name_zh': '鲁部夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lubu xianggong', 'God_Name_zh': '鲁部相公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lubu yima', 'God_Name_zh': '鲁部姨妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lubu zhengshen', 'God_Name_zh': '鲁部正神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lubu zhongjun', 'God_Name_zh': '鲁部中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lu Dongbin', 'God_Name_zh': '吕洞宾', 'Aliases': '{}'}
# {}
# {'God_Name': 'Luer mamu', 'God_Name_zh': '鹿儿马母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu dama', 'God_Name_zh': '芦(鲁)府大妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu daren', 'God_Name_zh': '鲁府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu dasheng', 'God_Name_zh': '鲁府大神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu furen', 'God_Name_zh': '鲁府夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu gongpo', 'God_Name_zh': '卢府公婆', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu jungong', 'God_Name_zh': '鲁府军公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu taizi', 'God_Name_zh': '鲁府太子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu xiangban', 'God_Name_zh': '鲁府相班', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu xianggong', 'God_Name_zh': '鲁府相公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu xianggong furen', 'God_Name_zh': '鲁府相公夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lufu yima', 'God_Name_zh': '鲁府姨妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lugong', 'God_Name_zh': '鲁公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lugong dianshuai', 'God_Name_zh': '鲁公殿帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Luma', 'God_Name_zh': '鲁妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lumu niangniang', 'God_Name_zh': '鲁母娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lu sheren', 'God_Name_zh': '卢舍人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lushi erniang', 'God_Name_zh': '芦氏二娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lushi furen', 'God_Name_zh': '卢氏夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lu Wenhui', 'God_Name_zh': '卢文辉', 'Aliases': '{}'}
# {}
# {'God_Name': 'Lu Xiansheng', 'God_Name_zh': '卢先生', 'Aliases': '{}'}
# {Lüzu xianshi}
# {'God_Name': 'Luzu xianshi', 'God_Name_zh': '吕祖仙师', 'Aliases': '{Lüzu xianshi}'}
# {}
# {'God_Name': 'Luofu daren', 'God_Name_zh': '罗府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Luotian dasheng', 'God_Name_zh': '罗天大圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Luo yuanshuai', 'God_Name_zh': '罗元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ma daren', 'God_Name_zh': '马大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mafu shenjiang', 'God_Name_zh': '马府神将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Magong daren', 'God_Name_zh': '马公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Magong shengjun', 'God_Name_zh': '马公圣君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Magong taishi', 'God_Name_zh': '马公太师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ma jiangjun', 'God_Name_zh': '马将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mamian', 'God_Name_zh': '马面', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mashi furen', 'God_Name_zh': '马氏夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ma Yuan jiangjun', 'God_Name_zh': '马援将军', 'Aliases': '{}'}
# {Magong yuanshuai}
# {'God_Name': 'Ma yuanshuai', 'God_Name_zh': '马元帅(马公元帅)', 'Aliases': '{Magong yuanshuai}'}
# {}
# {'God_Name': 'Mazu', 'God_Name_zh': '妈祖', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mao', 'God_Name_zh': 'xianzushi', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mei boye', 'God_Name_zh': '梅伯爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Meihua sanniang', 'God_Name_zh': '梅花三娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Milefo', 'God_Name_zh': '弥勒佛', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mituo dajiang', 'God_Name_zh': '弥陀大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Miaoguan dashi', 'God_Name_zh': '妙观大师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Miaoying zushi', 'God_Name_zh': '妙应祖师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Mu yuanshuai', 'God_Name_zh': '牟元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Nan beidou xingjun', 'God_Name_zh': '南北斗星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Nandou xingjun', 'God_Name_zh': '南斗星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Nanyue heng jiangjun', 'God_Name_zh': '南岳衡将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Nezha taizi', 'God_Name_zh': '哪咤太子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Niushan jiangjun', 'God_Name_zh': '牛山将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Niutou', 'God_Name_zh': '牛头', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ou daren', 'God_Name_zh': '欧大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ougong yuanshuai', 'God_Name_zh': '欧公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Oushi furen', 'God_Name_zh': '欧氏夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Oushi xianfei', 'God_Name_zh': '欧氏仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Oushi xiangu', 'God_Name_zh': '欧氏仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Pangu dijun', 'God_Name_zh': '盘古帝君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Panguan', 'God_Name_zh': '判官', 'Aliases': '{}'}
# {}
# {'God_Name': 'Panggong shenghou', 'God_Name_zh': '庞公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Peng daren', 'God_Name_zh': '蓬大人', 'Aliases': '{}'}
# {Penggong daren}
# {'God_Name': 'Penggong', 'God_Name_zh': '蓬公(大人)', 'Aliases': '{Penggong daren}'}
# {}
# {'God_Name': 'Peng jiangjun', 'God_Name_zh': '彭将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Peng taishan', 'God_Name_zh': '彭泰山', 'Aliases': '{}'}
# {}
# {'God_Name': 'Peng zhongjun', 'God_Name_zh': '彭中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Pu’an xianshi', 'God_Name_zh': '普庵仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Puhua tianzun', 'God_Name_zh': '普化天尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Puji shenghou', 'God_Name_zh': '普济圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Puxian', 'God_Name_zh': '普贤', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qitian dasheng', 'God_Name_zh': '齐天大圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qixing niangniang', 'God_Name_zh': '七星娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiye', 'God_Name_zh': '七爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qianliyan', 'God_Name_zh': '千里眼', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qianshi shengfei', 'God_Name_zh': '钱氏圣妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qianshi xianfei', 'God_Name_zh': '钱氏仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qian Siniang', 'God_Name_zh': '钱四娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qin mingdaren', 'God_Name_zh': '钦命仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qinggong zhenren', 'God_Name_zh': '清宫真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qin jin zhenren', 'God_Name_zh': '青巾真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qingshan wanggong', 'God_Name_zh': '青山王公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiongcang tiandi', 'God_Name_zh': '穹苍天地', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiu eryuanshuai', 'God_Name_zh': '邱二元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiugong jiangjun', 'God_Name_zh': '丘公将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiugong shenghou', 'God_Name_zh': '邱公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiugong xianshi', 'God_Name_zh': '邱公仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiu laoye', 'God_Name_zh': '邱老爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Qiu yuanshuai', 'God_Name_zh': '邱元帅', 'Aliases': '{}'}
# {Rulaifo}
# {'God_Name': 'Rulai fozu', 'God_Name_zh': '如来', 'Aliases': '{Rulaifo}'}
# {}
# {'God_Name': 'Ruigou shenghou', 'God_Name_zh': '瑞沟圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ruigou shengwang', 'God_Name_zh': '瑞沟圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ruigou xianggong', 'God_Name_zh': '瑞沟相公', 'Aliases': '{}'}
# {}
# {'God_Name': 'San daren', 'God_Name_zh': '三大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sandian zhenjun', 'God_Name_zh': '三殿真君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanfeng zhenren', 'God_Name_zh': '三丰真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'San furen', 'God_Name_zh': '三夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanguan dadi', 'God_Name_zh': '三官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanjiao faye', 'God_Name_zh': '三教法爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanjiao xiansheng', 'God_Name_zh': '三教先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanjiuku', 'God_Name_zh': '三救苦', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sansheng zhenjun', 'God_Name_zh': '三圣真君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanshiqiwei Daren', 'God_Name_zh': '三十七位大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanwei furen', 'God_Name_zh': '三位夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanwei xianshi', 'God_Name_zh': '三位仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanxingjun', 'God_Name_zh': '三星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sanyan wuyan', 'God_Name_zh': '三眼五眼', 'Aliases': '{}'}
# {Sanwei daye}
# {'God_Name': 'Sanye', 'God_Name_zh': '三爷', 'Aliases': '{Sanwei daye}'}
# {三一教主, Sanyi xiansheng}
# {'God_Name': 'Sanyi jiaozhu', 'God_Name_zh': '三一教主', 'Aliases': '{三一教主, Sanyi xiansheng}'}
# {}
# {'God_Name': 'Sanyuan dajiang', 'God_Name_zh': '三员大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'San zhenfo', 'God_Name_zh': '三真佛', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shancai', 'God_Name_zh': '善才', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shancai dongzi', 'God_Name_zh': '善才童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shandian cimu', 'God_Name_zh': '闪电云母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shan jiangjun', 'God_Name_zh': '山将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shanshen', 'God_Name_zh': '山神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shangyang zhenren', 'God_Name_zh': '上阳真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shegong', 'God_Name_zh': '社公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shegong, Shema', 'God_Name_zh': '社公,社妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shema', 'God_Name_zh': '社妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'She taijun', 'God_Name_zh': '余太君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shen daifu', 'God_Name_zh': '沈大夫', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shennongshi', 'God_Name_zh': '神农氏', 'Aliases': '{}'}
# {Sheng fu}
# {'God_Name': 'Shengmu', 'God_Name_zh': '圣母,圣父', 'Aliases': '{Sheng fu}'}
# {}
# {'God_Name': 'Shengzishen', 'God_Name_zh': '圣子神', 'Aliases': '{}'}
# {Shijia mouni}
# {'God_Name': 'Shijiamouni', 'God_Name_zh': '释伽牟尼', 'Aliases': '{Shijia mouni}'}
# {}
# {'God_Name': 'Shijia wenfo', 'God_Name_zh': '释伽文佛', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shi jiangjun', 'God_Name_zh': '施将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shitai', 'God_Name_zh': 'daoren', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shiwu ma', 'God_Name_zh': '十五妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shizhe zhongjun', 'God_Name_zh': '侍者中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shi zuoye', 'God_Name_zh': '史佐爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shuaigong shenghou', 'God_Name_zh': '帅公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shuiguan dadi', 'God_Name_zh': '水官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shuizhu xianshi', 'God_Name_zh': '水珠仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shunfenger', 'God_Name_zh': '顺风耳', 'Aliases': '{}'}
# {}
# {'God_Name': 'Shuntian shengmu', 'God_Name_zh': '顺天圣母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sida jiangjun', 'God_Name_zh': '四大将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Si dajiang (Liu, Zhang, Zhao, Su)', 'God_Name_zh': '四大将(刘,张,赵,苏)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sida jinggang', 'God_Name_zh': '四大金刚', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sida yuanshuai', 'God_Name_zh': '四大元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sihai longwang', 'God_Name_zh': '四海龙王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sima shenghou', 'God_Name_zh': '司马圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sima shengwang', 'God_Name_zh': '司马圣王(张巡)', 'Aliases': '{}'}
# {Si mengjiang(Chen, Zheng, Qiu, Liu)}
# {'God_Name': 'Si mengjiang', 'God_Name_zh': '四猛将/四大将军', 'Aliases': '{Si mengjiang(Chen, Zheng, Qiu, Liu)}'}
# {}
# {'God_Name': 'Si tongzi', 'God_Name_zh': '四童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Siye', 'God_Name_zh': '四爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sizhou wenfou', 'God_Name_zh': '泗州文佛', 'Aliases': '{}'}
# {}
# {'God_Name': 'Song daren', 'God_Name_zh': '宋大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Song yuanshuai', 'God_Name_zh': '宋元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Song zhongjun', 'God_Name_zh': '宋中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Su dajiang', 'God_Name_zh': '苏大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Sugong ershi', 'God_Name_zh': '苏公二使', 'Aliases': '{}'}
# {}
# {'God_Name': 'Taishan kangwang', 'God_Name_zh': '泰山康王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Taishang laojun', 'God_Name_zh': '太上老君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Taiyi tianzun', 'God_Name_zh': '太乙天尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Taiyi xiangu', 'God_Name_zh': '太乙仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tang dajiang', 'God_Name_zh': '唐大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tang sanzang', 'God_Name_zh': '唐三藏', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tangshi yima', 'God_Name_zh': '汤氏姨妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Taohua shengmu', 'God_Name_zh': '桃花圣母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiandi', 'God_Name_zh': '天地', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiandijun qinshi', 'God_Name_zh': '天地君亲师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiangang', 'God_Name_zh': '天罡', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiangong', 'God_Name_zh': '田公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiangong daren', 'God_Name_zh': '天公大人', 'Aliases': '{}'}
# {田公元帅}
# {'God_Name': 'Tiangong yuanshuai', 'God_Name_zh': '田公元帅', 'Aliases': '{田公元帅}'}
# {}
# {'God_Name': 'Tianguan dadi', 'God_Name_zh': '天官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tianhou shengmu', 'God_Name_zh': '天后圣母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiankui yuanshuai', 'God_Name_zh': '天魁元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tianmen Zhu zhizun', 'God_Name_zh': '天门朱至尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tianmin zongshi', 'God_Name_zh': '田民宗师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tianpeng yuanshuai', 'God_Name_zh': '天蓬元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tianqian shengmu', 'God_Name_zh': '天前圣母', 'Aliases': '{}'}
# {Tianshang shengmu (Mazu)}
# {'God_Name': 'Tianshang shengmu', 'God_Name_zh': '天上圣母', 'Aliases': '{Tianshang shengmu (Mazu)}'}
# {}
# {'God_Name': 'Tianshang wuji shengmu', 'God_Name_zh': '天上无极圣母', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiegong taishi', 'God_Name_zh': '铁公太师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiegong yuanshuai', 'God_Name_zh': '铁公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tiehuan tongzi', 'God_Name_zh': '铁环童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tielu zungong', 'God_Name_zh': '铁炉尊公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tongling shenghou', 'God_Name_zh': '统领圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tongzi', 'God_Name_zh': '童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Touling', 'God_Name_zh': '头领', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tudigong', 'God_Name_zh': '土地公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tugong yuanshi', 'God_Name_zh': '屠公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Tuzhu mingwang', 'God_Name_zh': '土主明王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wanfu dama', 'God_Name_zh': '万府大妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wanlier', 'God_Name_zh': '万里耳', 'Aliases': '{}'}
# {Wangfu daren}
# {'God_Name': 'Wang daren', 'God_Name_zh': '王大人', 'Aliases': '{Wangfu daren}'}
# {}
# {'God_Name': 'Wang daye', 'God_Name_zh': '王大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wanggong daren', 'God_Name_zh': '王公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wanggong shenghou', 'God_Name_zh': '王公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wang jiangjun', 'God_Name_zh': '王将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wang lingguan', 'God_Name_zh': '王灵官', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wangmu niangniang', 'God_Name_zh': '王母娘娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wang tianguan', 'God_Name_zh': '王天官', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wang Yong', 'God_Name_zh': '王用', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wang yuanshuai', 'God_Name_zh': '王元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wang zhongjun', 'God_Name_zh': '王中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weigong shenghou', 'God_Name_zh': '魏公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weigong taibao', 'God_Name_zh': '魏公太保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wei jiangjun', 'God_Name_zh': '魏将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weituo', 'God_Name_zh': '韦陀', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weituo and Jialan', 'God_Name_zh': '陀和伽蓝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weituo hufa', 'God_Name_zh': '韦陀护法', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weituo zuntian', 'God_Name_zh': '韦驼尊天', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weituo zunzhe', 'God_Name_zh': '韦驮尊者', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weiwu jiangjun', 'God_Name_zh': '威武将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Weiwu shenghou', 'God_Name_zh': '威武圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wei zhongjun', 'God_Name_zh': '尉中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wencao', 'God_Name_zh': '文曹', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wencao wupan', 'God_Name_zh': '文曹武判', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenchang dijun', 'God_Name_zh': '文昌帝君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wen daren', 'God_Name_zh': '瘟大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenlai yuanshuai', 'God_Name_zh': '文赖元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenlin shuima', 'God_Name_zh': '文临水妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenshu', 'God_Name_zh': '文殊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wen taishi', 'God_Name_zh': '闻太师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenwu liesheng', 'God_Name_zh': '文武列圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenwu panguan', 'God_Name_zh': '文武判官', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenwu siguan dadi', 'God_Name_zh': '文武四官大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenwu zhusheng', 'God_Name_zh': '文武诸神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wenye', 'God_Name_zh': '温爷', 'Aliases': '{}'}
# {Wen yuanshuai, Kang yuanshuai, Ma yuanshuai, Zhao yuanshuai, Wengong yuanshuai}
# {'God_Name': 'Wen, Kang, Ma, Zhao yuanshuai', 'God_Name_zh': '温,康,马,赵元帅', 'Aliases': '{Wen yuanshuai, Kang yuanshuai, Ma yuanshuai, Zhao yuanshuai, Wengong yuanshuai}'}
# {}
# {'God_Name': 'Wenggong daren', 'God_Name_zh': '翁公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wugong dutong', 'God_Name_zh': '吴公都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuan shengwang', 'God_Name_zh': '武按圣王(雷万春)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wubu yuanshuai', 'God_Name_zh': '五部元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wu daren', 'God_Name_zh': '吴大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wudiye', 'God_Name_zh': '五帝爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wufu daren', 'God_Name_zh': '乌府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wufu zhongjun', 'God_Name_zh': '吴府中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wugong', 'God_Name_zh': '武公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wugong dutong', 'God_Name_zh': '吴公都统(圣侯)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wugong jishi', 'God_Name_zh': '吴公吉使', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wugu daxian', 'God_Name_zh': '五谷大仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wugu shenxian', 'God_Name_zh': '五谷神仙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuhu jialuo', 'God_Name_zh': '五虎迦逻', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuhua tongzi', 'God_Name_zh': '五花童子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuhuang dadi', 'God_Name_zh': '五皇大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wu jiangjun', 'God_Name_zh': '乌将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wulu jiangjun', 'God_Name_zh': '五路将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wupan', 'God_Name_zh': '武判', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wusheng tianfei', 'God_Name_zh': '吴圣天妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wusheng xianfei', 'God_Name_zh': '吴圣仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wushi shengfei', 'God_Name_zh': '吴氏圣妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wushi xiansheng', 'God_Name_zh': '吴氏先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wusima', 'God_Name_zh': '武司马', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wutan liesheng', 'God_Name_zh': '五坛列圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wutan zhizun', 'God_Name_zh': '五坛至尊', 'Aliases': '{}'}
# {Wugong shenghou}
# {'God_Name': 'Wutian shenghou', 'God_Name_zh': '吾天圣侯(伍公圣侯)', 'Aliases': '{Wugong shenghou}'}
# {}
# {'God_Name': 'Wuxian dadi', 'God_Name_zh': '五显大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuxian faye', 'God_Name_zh': '五显法爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuxian lingguan', 'God_Name_zh': '五显灵官', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuxian lingguan Ma yuanshuai', 'God_Name_zh': '五显灵官马元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuxian Ma yuanshuai', 'God_Name_zh': '五显马元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wu xianggong', 'God_Name_zh': '武相公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wuxiong', 'God_Name_zh': '五兄', 'Aliases': '{}'}
# {}
# {'God_Name': 'Wu yuanshuai', 'God_Name_zh': '伍元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xi daye', 'God_Name_zh': '西大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xigong', 'God_Name_zh': '喜公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xipo', 'God_Name_zh': '喜婆', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xianbao longnu', 'God_Name_zh': '献宝龙', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiangong', 'God_Name_zh': '仙公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiangong ajiu', 'God_Name_zh': '仙公阿舅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xianling dawang', 'God_Name_zh': '显灵大王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xianzhu longnu', 'God_Name_zh': '献珠龙女', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiao daye', 'God_Name_zh': '肖大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiaogong shenghou', 'God_Name_zh': '肖公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiaogong shengjun', 'God_Name_zh': '萧公圣君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiao sheng xian shi', 'God_Name_zh': '萧圣先师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiaosheng xianshi', 'God_Name_zh': '萧圣先师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiao zhongguan', 'God_Name_zh': '(敕封)萧总管', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiao zhongjun', 'God_Name_zh': '肖中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xie daye', 'God_Name_zh': '谢大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiefu daxiong', 'God_Name_zh': '谢府大兄', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiehu jiangjun 协', 'God_Name_zh': '(谢)虎将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xieshun shenghou', 'God_Name_zh': '协顺圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xietian dadi', 'God_Name_zh': '协天大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xiling Kongdaren', 'God_Name_zh': '西岭孔大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xinghua chenghuang', 'God_Name_zh': '兴化城隍', 'Aliases': '{}'}
# {Xufu daren, Xufe daren}
# {'God_Name': 'Xu daren', 'God_Name_zh': '徐大人', 'Aliases': '{Xufu daren, Xufe daren}'}
# {}
# {'God_Name': 'Xugong taibao', 'God_Name_zh': '徐公太保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xu guniang', 'God_Name_zh': '徐姑娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xu jiangjun', 'God_Name_zh': '徐将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xushi shengfei', 'God_Name_zh': '许氏圣妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xu Yuan', 'God_Name_zh': '许远', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xuantan gong', 'God_Name_zh': '玄坛公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xuantan yuanshuai', 'God_Name_zh': '玄坛元帅', 'Aliases': '{}'}
# {Xuandi}
# {'God_Name': 'Xuantian dadi', 'God_Name_zh': '玄天大帝(武)', 'Aliases': '{Xuandi}'}
# {}
# {'God_Name': 'Xuantian shangdi', 'God_Name_zh': '玄天上帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Xue daren', 'God_Name_zh': '薛大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yahan zhongjun', 'God_Name_zh': '亚汉中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yawen dutong dashen', 'God_Name_zh': '押瘟都统大神', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangfu dagong', 'God_Name_zh': '杨府大公', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangfu dama', 'God_Name_zh': '杨府大妈', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangfu bajiang', 'God_Name_zh': '杨府八将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangfu Jiuniang', 'God_Name_zh': '杨府九娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangfu zhongjun', 'God_Name_zh': '杨府中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangfu daren', 'God_Name_zh': '杨府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yanggong ershi', 'God_Name_zh': '杨公二使', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yanggong taishi', 'God_Name_zh': '杨公太师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yanggong yuanshuai', 'God_Name_zh': '杨公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yang Jiye', 'God_Name_zh': '杨继业', 'Aliases': '{}'}
# {Yangmen bajiang, Yangfu bajiang}
# {'God_Name': 'Yangjia bajiang', 'God_Name_zh': '杨家（门府）八将', 'Aliases': '{Yangmen bajiang, Yangfu bajiang}'}
# {}
# {'God_Name': 'Yang jiuniang', 'God_Name_zh': '杨九娘', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangsheng', 'God_Name_zh': '杨圣中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yangshi xiangu', 'God_Name_zh': '杨氏仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yang yuanshuai', 'God_Name_zh': '杨元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yang Zongbao', 'God_Name_zh': '杨宗保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yaogong yuanshuai', 'God_Name_zh': '姚公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yaoshi furen', 'God_Name_zh': '姚氏夫人', 'Aliases': '{}'}
# {shema}
# {'God_Name': 'Yide furen', 'God_Name_zh': '懿德夫人(社妈)', 'Aliases': '{shema}'}
# {}
# {'God_Name': 'Yide xianfei', 'God_Name_zh': '懿德仙妃', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yi dian zhen jun', 'God_Name_zh': '一殿真君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yilie qiansui', 'God_Name_zh': '伊烈千岁', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yima furen', 'God_Name_zh': '姨妈夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yima yuanjun', 'God_Name_zh': '姨妈元君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yinzhu xiangu', 'God_Name_zh': '银主仙姑', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yingji houwang', 'God_Name_zh': '英济侯王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yinglie Miao jiangjun', 'God_Name_zh': '英烈妙将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yinglie shengwang', 'God_Name_zh': '英烈圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yongquan zushi', 'God_Name_zh': '永泉祖师', 'Aliases': '{}'}
# {}
# {'God_Name': 'You zhongjun', 'God_Name_zh': '游中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yufeng Yinglie shenghou', 'God_Name_zh': '玉封英烈圣王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yufu zhongjun', 'God_Name_zh': '余府中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yugong tai bao', 'God_Name_zh': '余公太保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yugong yuanshuai', 'God_Name_zh': '余公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuhuang dadi', 'God_Name_zh': '玉皇大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuhuang shangdi', 'God_Name_zh': '玉皇上帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuhuang taizi', 'God_Name_zh': '玉皇太子', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuhuang zhizun', 'God_Name_zh': '玉皇至尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yu qiren', 'God_Name_zh': '玉旗人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuqian zhongjun', 'God_Name_zh': '御前中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yushi', 'God_Name_zh': '雨师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yushu dadi', 'God_Name_zh': '玉枢大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yushu tianzun', 'God_Name_zh': '玉枢天尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yutong jiangjun', 'God_Name_zh': '玉通将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuzhao xianshi', 'God_Name_zh': '玉昭仙师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuan daren', 'God_Name_zh': '袁大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuansheng daren', 'God_Name_zh': '袁圣大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuanshi tianzun', 'God_Name_zh': '元始天尊', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuantian shangdi', 'God_Name_zh': '元天大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuegong daren', 'God_Name_zh': '岳公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Yuewang dadi', 'God_Name_zh': '越王大帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang Bao', 'God_Name_zh': '张苞', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang daren', 'God_Name_zh': '张大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhanggong shengjun', 'God_Name_zh': '张公圣君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhanggong yuanshuai', 'God_Name_zh': '张公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang Hongdu', 'God_Name_zh': '张洪都', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang jiangjun', 'God_Name_zh': '张将军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang Sanfeng', 'God_Name_zh': '张三丰', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhangshi furen', 'God_Name_zh': '张氏夫人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang situ', 'God_Name_zh': '张司徒', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhang tianshi', 'God_Name_zh': '张天师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhao Gongming', 'God_Name_zh': '赵公明', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhaogong taishi', 'God_Name_zh': '赵公太师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhaogong yuanshuai', 'God_Name_zh': '赵公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhaoli daye', 'God_Name_zh': '昭利大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhaoling shengjun', 'God_Name_zh': '昭灵圣君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhaoshun shengwang', 'God_Name_zh': '昭顺圣王(江国舅)', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zheng daifu', 'God_Name_zh': '郑大夫', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhenggong dutong', 'God_Name_zh': '郑公都统', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhenggong sheren', 'God_Name_zh': '郑公舍人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhenggong shenghou', 'God_Name_zh': '郑公圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhengshun shengwang', 'God_Name_zh': '正顺圣王', 'Aliases': '{}'}
# {Wuxian huaguang dadi, Wang Lingguan}
# {'God_Name': 'Zhengyi lingguan', 'God_Name_zh': '正一灵官(五显华光大帝)', 'Aliases': '{Wuxian huaguang dadi, Wang Lingguan}'}
# {}
# {'God_Name': 'Zheng Yue', 'God_Name_zh': '郑岳', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhida xiansheng', 'God_Name_zh': '智达先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhongji shenghou', 'God_Name_zh': '忠济圣侯', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhongjun (Zhong junye)', 'God_Name_zh': '中军(中军爷)', 'Aliases': '{}'}
# {shengjun}
# {'God_Name': 'Zhong Kui', 'God_Name_zh': '钟馗(圣君)', 'Aliases': '{shengjun}'}
# {}
# {'God_Name': 'Zhongtian dasheng', 'God_Name_zh': '中天大圣', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhongyou shenghou', 'God_Name_zh': '忠佑圣候', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhong yuanshuai', 'God_Name_zh': '钟元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhou Cang', 'God_Name_zh': '周仓', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhou dajiang', 'God_Name_zh': '周大将', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhou daren', 'God_Name_zh': '周大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhou daye', 'God_Name_zh': '周大爷', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhou daifu', 'God_Name_zh': '周大夫', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhougong yuanshuai', 'God_Name_zh': '周公元帅', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhouguang pingwang', 'God_Name_zh': '周广平王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhou taibao', 'God_Name_zh': '周太保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhu daifu', 'God_Name_zh': '煮大夫', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhufu daren', 'God_Name_zh': '朱府大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhugong daren', 'God_Name_zh': '朱公大人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhu Huixu', 'God_Name_zh': '朱慧虚', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhunti wenfo', 'God_Name_zh': '准提文佛', 'Aliases': '{}'}
# {Zhushen dadi}
# {'God_Name': 'Zhusheng dadi', 'God_Name_zh': '注生大帝', 'Aliases': '{Zhushen dadi}'}
# {}
# {'God_Name': 'Zhusheng shangdi', 'God_Name_zh': '注生上帝', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhu xiansheng', 'God_Name_zh': '朱先生', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhu yuanshuai', 'God_Name_zh': '朱元帅', 'Aliases': '{}'}
# {Zhu Xi}
# {'God_Name': 'Zhuzi', 'God_Name_zh': '朱子', 'Aliases': '{Zhu Xi}'}
# {}
# {'God_Name': 'Zhuzi shengjun', 'God_Name_zh': '朱紫圣君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhuogong taibao', 'God_Name_zh': '卓公太保', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhuojiao zhongjun', 'God_Name_zh': '卓角中军', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhuogong zhoushi', 'God_Name_zh': '卓公咒师', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhuoshi zhenren', 'God_Name_zh': '卓氏真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhuo Wanchun', 'God_Name_zh': '卓晚春', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zhuozu zhenren', 'God_Name_zh': '卓祖真人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Ziwei xingjun', 'God_Name_zh': '紫微（薇）星君', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zouma sheren', 'God_Name_zh': '走马舍人', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zunzhu mingwang', 'God_Name_zh': '尊主明王', 'Aliases': '{}'}
# {}
# {'God_Name': 'Zuoyou jiangjun', 'God_Name_zh': '左右将军', 'Aliases': '{}'}

# %%
# DO NOT USE
# Parse village data to a CSV which can be imported into PostGIS

import json, csv

with open('./output/village_index.json') as infile:
    
    indata = json.load(infile)
    data_out = []
    for Alliance in indata:
        for Village in Alliance["Villages"]:
            data_out.append({
                "UID_V": Village["UID_V"],
                "UID_A": Alliance["UID_A"]
            })
    
    with open("./output/alliance_membership.csv", "w") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=data_out[0].keys(),quoting=csv.QUOTE_ALL, escapechar='\\')
        writer.writeheader()
        writer.writerows(data_out)

# %%
# DO NOT USE
# Parse village data to a CSV which can be imported into PostGIS

import json, csv

with open('./output/village_master.json') as infile:
    
    indata = json.load(infile)
    data_out = []
    
    for Village in indata:
        data_out.append({
            "UID_V": Village["UID"],
            "Population": Village["Population"]
        })
        
    print(data_out)
    
    with open("./output/pop.csv", "w") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=data_out[0].keys(), escapechar='\\')
        writer.writeheader()
        writer.writerows(data_out)
# Out:
# [{'UID_V': 'V001', 'Population': '800'}, {'UID_V': 'V002', 'Population': '150'}, {'UID_V': 'V003', 'Population': '200'}, {'UID_V': 'V004', 'Population': '800'}, {'UID_V': 'V005', 'Population': '210'}, {'UID_V': 'V006', 'Population': '1000'}, {'UID_V': 'V007', 'Population': '800'}, {'UID_V': 'V008', 'Population': '2400'}, {'UID_V': 'V009', 'Population': '1500'}, {'UID_V': 'V010', 'Population': '500'}, {'UID_V': 'V011', 'Population': '1300'}, {'UID_V': 'V012', 'Population': '500'}, {'UID_V': 'V013', 'Population': '655'}, {'UID_V': 'V014', 'Population': '509'}, {'UID_V': 'V015', 'Population': '600'}, {'UID_V': 'V016', 'Population': '500'}, {'UID_V': 'V017', 'Population': '500'}, {'UID_V': 'V018', 'Population': '1000'}, {'UID_V': 'V019', 'Population': '600'}, {'UID_V': 'V020', 'Population': '800'}, {'UID_V': 'V021', 'Population': '400'}, {'UID_V': 'V022', 'Population': '300'}, {'UID_V': 'V023', 'Population': '100'}, {'UID_V': 'V024', 'Population': '2400'}, {'UID_V': 'V025', 'Population': '600'}, {'UID_V': 'V026', 'Population': '200'}, {'UID_V': 'V027', 'Population': '600'}, {'UID_V': 'V028', 'Population': '1000'}, {'UID_V': 'V029', 'Population': '1500'}, {'UID_V': 'V030', 'Population': '700'}, {'UID_V': 'V031', 'Population': '1100'}, {'UID_V': 'V032', 'Population': '1300'}, {'UID_V': 'V033', 'Population': '1200'}, {'UID_V': 'V034', 'Population': '600'}, {'UID_V': 'V035', 'Population': '600'}, {'UID_V': 'V036', 'Population': '300'}, {'UID_V': 'V037', 'Population': '2000'}, {'UID_V': 'V038', 'Population': '800'}, {'UID_V': 'V039', 'Population': '1400'}, {'UID_V': 'V040', 'Population': '335'}, {'UID_V': 'V041', 'Population': '455'}, {'UID_V': 'V042', 'Population': '1100'}, {'UID_V': 'V043', 'Population': '1300'}, {'UID_V': 'V044', 'Population': '800'}, {'UID_V': 'V045', 'Population': '363'}, {'UID_V': 'V046', 'Population': '263'}, {'UID_V': 'V047', 'Population': '320'}, {'UID_V': 'V048', 'Population': '126'}, {'UID_V': 'V049', 'Population': '212'}, {'UID_V': 'V050', 'Population': '300'}, {'UID_V': 'V051', 'Population': '500'}, {'UID_V': 'V052', 'Population': '600'}, {'UID_V': 'V053', 'Population': '200'}, {'UID_V': 'V054', 'Population': '800'}, {'UID_V': 'V055', 'Population': '250'}, {'UID_V': 'V056', 'Population': '826'}, {'UID_V': 'V057', 'Population': '585'}, {'UID_V': 'V058', 'Population': '300'}, {'UID_V': 'V059', 'Population': '1500'}, {'UID_V': 'V060', 'Population': '1000'}, {'UID_V': 'V061', 'Population': '1000'}, {'UID_V': 'V062', 'Population': '1200'}, {'UID_V': 'V063', 'Population': '3000'}, {'UID_V': 'V064', 'Population': '300'}, {'UID_V': 'V065', 'Population': '1000'}, {'UID_V': 'V066', 'Population': '1700'}, {'UID_V': 'V067', 'Population': '300'}, {'UID_V': 'V068', 'Population': '800'}, {'UID_V': 'V069', 'Population': '500'}, {'UID_V': 'V070', 'Population': '300'}, {'UID_V': 'V071', 'Population': '965'}, {'UID_V': 'V072', 'Population': '300'}, {'UID_V': 'V073', 'Population': '949'}, {'UID_V': 'V074', 'Population': '400'}, {'UID_V': 'V075', 'Population': '1000'}, {'UID_V': 'V076', 'Population': '200'}, {'UID_V': 'V077', 'Population': '650'}, {'UID_V': 'V078', 'Population': '242'}, {'UID_V': 'V079', 'Population': ''}, {'UID_V': 'V080', 'Population': '600'}, {'UID_V': 'V081', 'Population': '600'}, {'UID_V': 'V082', 'Population': '900'}, {'UID_V': 'V083', 'Population': '866'}, {'UID_V': 'V084', 'Population': '600'}, {'UID_V': 'V085', 'Population': '500'}, {'UID_V': 'V086', 'Population': '1500'}, {'UID_V': 'V087', 'Population': '4366'}, {'UID_V': 'V088', 'Population': '2000'}, {'UID_V': 'V089', 'Population': '551'}, {'UID_V': 'V090', 'Population': '600'}, {'UID_V': 'V091', 'Population': '500'}, {'UID_V': 'V092', 'Population': '600'}, {'UID_V': 'V093', 'Population': '1500'}, {'UID_V': 'V094', 'Population': '300'}, {'UID_V': 'V095', 'Population': '500'}, {'UID_V': 'V096', 'Population': '900'}, {'UID_V': 'V097', 'Population': '492'}, {'UID_V': 'V098', 'Population': '185'}, {'UID_V': 'V099', 'Population': '3900'}, {'UID_V': 'V10 ...

# %%
# DO NOT USE
# Process text of "Village_Temple" entries for each village, extracting major gods and temple names, etc.

import json, csv, re

with open('./output/village_master.json') as infile:
    
    indata = json.load(infile)
    data_out = []
    primaryGod_out = []
    secondaryGod_out = []

    with open('./output/god_names.json') as godfile:
    
        goddata = json.load(godfile)
    
    
        for v_entry in indata:
            templeNo = 0
            temple_entry = v_entry["Raw_Text"]["Village_Temples"]
            temples_array = re.split("(?:^|\.\s|\)\s)\d+\)(?=\s[A-Z])", temple_entry)
            for t in temples_array:
                
                
                if t == "":
                    continue
                else:
                    
                    templeNo += 1
                    
                     # identify primary and secondary
                    foo = re.split("Secondary", t)
                    primarygods =[]
                    secondarygods = []
                    
                    primaryBlock = foo[0]
                    for godEntry in goddata:
                        if godEntry["Name"] in primaryBlock:
                            if not godEntry["Name"] in primarygods:
                                primarygods.append(godEntry["Name"])
                        else:
                            for aliases in godEntry["Aliases"]:
                                if aliases in primaryBlock:
                                    if not godEntry["Name"] in primarygods:
                                        primarygods.append(godEntry["Name"]) 
                                                            
                    if len(foo) == 2:
                        secondaryblock = foo[1]
                        for godEntry in goddata:
                            if godEntry["Name"] in secondaryblock:
                                if not godEntry["Name"] in secondarygods:
                                    secondarygods.append(godEntry["Name"])
                            else:
                                for aliases in godEntry["Aliases"]:
                                    if aliases in secondaryblock:
                                        if not godEntry["Name"] in secondarygods:
                                            secondarygods.append(godEntry["Name"])
                    
                    firstHanzi = re.search("([\u4E00-\u9FCC\u3400-\u4DB5\uFA0E\uFA0F\uFA11\uFA13\uFA14\uFA1F\uFA21\uFA23\uFA24\uFA27-\uFA29]|[\ud840-\ud868][\udc00-\udfff]|\ud869[\udc00-\uded6\udf00-\udfff]|[\ud86a-\ud86c][\udc00-\udfff]|\ud86d[\udc00-\udf34\udf40-\udfff]|\ud86e[\udc00-\udc1d])+", t)
                    uid_t = v_entry["UID"] + "-" + str(templeNo)
                    
                    buffer = {
                        "uid_t": uid_t,
                        "name": t[0:firstHanzi.span(0)[0]].strip(),
                        "name_zh": firstHanzi.group(0),
                        "village": v_entry["UID"],
                        "raw_Text": t
                    }
                    
                    data_out.append(buffer)
                    
                    for god_entry in primarygods:
                        buffer2 = {
                            "uid_t": uid_t,
                            "god_name":god_entry
                        }
                        
                        primaryGod_out.append(buffer2)
                        
                    for god_entry in secondarygods:
                        buffer2 = {
                            "uid_t": uid_t,
                            "god_name":god_entry
                        }
                        
                        secondaryGod_out.append(buffer2)
                        

with open("./output/secondary_gods.csv", "w") as outfile:
    writer = csv.DictWriter(outfile, fieldnames=secondaryGod_out[0].keys(), escapechar='\\')
    writer.writeheader()
    writer.writerows(secondaryGod_out)

with open("./output/primary_gods.csv", "w") as outfile:
    writer = csv.DictWriter(outfile, fieldnames=primaryGod_out[0].keys(), escapechar='\\')
    writer.writeheader()
    writer.writerows(primaryGod_out)
                    
with open("./output/temples.csv", "w") as outfile:
    writer = csv.DictWriter(outfile, fieldnames=data_out[0].keys(), escapechar='\\')
    writer.writeheader()
    writer.writerows(data_out)

# %%
# DO NOT USE
# Process text of "Yuanxiao processions" entries for each village, extracting major gods and temple names, etc.

import json, csv, re
from nltk.tokenize import sent_tokenize

with open('./output/village_master.json') as infile:
    indata = json.load(infile)
    ritualsout=[]
    
    with open('./output/god_names.json') as godfile:
        goddata = json.load(godfile)
    
        for entry in indata:
            entry_text = entry["Raw_Text"]["Rituals"]["Yuanxiao processions"]

            sentences = sent_tokenize(entry_text)
            buffer = ""
            array = []

            for sentence in sentences:
                match = re.search("(\d{1,2}\/\d{1,2}[\-\–]\d{1,2}|\d{1,2}\/\d{1,2}[\-\–]\d{1,2}\/\d{1,2}|\d{1,2}\/\d{1,2})", sentence)

                if match != None or re.search("lunar month",sentence):
                    if len(buffer) == 0:
                        array.append(buffer)
                        buffer = sentence
                    else:
                        array.append(buffer)
                        buffer = sentence
                else:
                    buffer = buffer + " " + sentence

            array.append(buffer)

            array = array[1:]

            entryno = 0

            for e in array:

                entryno = entryno + 1
                startdate = "MM-DD"
                enddate = "MM-DD"

                date = re.search("(\d{1,2}\/\d{1,2}[\-\–]\d{1,2}|\d{1,2}\/\d{1,2}[\-\–]\d{1,2}\/\d{1,2}|\d{1,2}\/\d{1,2})", e)
                if date != None:
                    if date.group(0).count("–") == 0:
                        alpha = re.split("/",date.group(0))
                        if len(alpha[0]) == 1:
                            alpha[0] = "0" + alpha[0]
                        if len(alpha[1]) == 1:
                            alpha[1] = "0" + alpha[1]

                        startdate = alpha[0] + "-" + alpha[1]
                        enddate = startdate

                    if date.group(0).count("/") == 2:
                        alpha = re.split("–",date.group(0))
                        bravo = re.split("/",alpha[0])
                        charlie = re.split("/",alpha[1])

                        if len(bravo[0]) == 1:
                            bravo[0] = "0" + bravo[0]
                        if len(bravo[1]) == 1:
                            bravo[1] = "0" + bravo[1]
                        if len(charlie[0]) == 1:
                            charlie[0] = "0" + charlie[0]
                        if len(charlie[1]) == 1:
                            charlie[1] = "0" + charlie[1]

                        startdate = bravo[0] + "-" + bravo[1]
                        enddate = charlie[0] + "-" + charlie[1]

                    if date.group(0).count("–") == 1 and date.group(0).count("/") == 1:
                        alpha = re.split("–",date.group(0))
                        bravo = re.split("/",alpha[0])

                        if len(bravo[0]) == 1:
                            bravo[0] = "0" + bravo[0]
                        if len(bravo[1]) == 1:
                            bravo[1] = "0" + bravo[1]
                        if len(alpha[0]) == 1:
                            alpha[0] = "0" + alpha[0]

                        startdate = bravo[0] + "-" + bravo[1]
                        enddate = bravo[0] + "-" + alpha[1]

                    gods_involved = []
                    for godEntry in goddata:

                        if godEntry["Name"] in e:
                            if not godEntry["Name"] in gods_involved:
                                gods_involved.append(godEntry["Name"])
                        else:
                            for aliases in godEntry["Aliases"]:
                                if aliases in gods_involved:
                                    if not godEntry["Name"] in gods_involved:
                                        gods_involved.append(godEntry["Name"])
                            for aliases in godEntry["Name_zh"]:
                                if aliases in gods_involved:
                                    if not godEntry["Name"] in gods_involved:
                                        gods_involved.append(godEntry["Name"])

                ritualsout.append({
                    "startdate": startdate,
                    "enddate": enddate,
                    "uid_r": entry["UID"]+"-"+str(entryno),
                    "text": e,
                    "gods_involved": gods_involved
                })

with open('./output/processions.json', 'w', encoding='utf8') as outfile:
    json.dump(ritualsout, outfile, ensure_ascii=False)
    
with open("./output/processions.csv", "w") as outfile:
    writer = csv.DictWriter(outfile, fieldnames=ritualsout[0].keys(), escapechar='\\')
    writer.writeheader()
    writer.writerows(ritualsout)

# %%
# DO NOT USE
# Process text of "Birthday Celerbations of the gods" entries for each village, extracting major gods and temple names, etc.

import json, csv, re
from nltk.tokenize import sent_tokenize

with open('./output/village_master.json') as infile:
    indata = json.load(infile)
    ritualsout=[]
    
    with open('./output/god_names.json') as godfile:
        goddata = json.load(godfile)
    
        for entry in indata:
            entry_text = entry["Raw_Text"]["Rituals"]["Birthday celebrations of the gods"]

            sentences = sent_tokenize(entry_text)
            buffer = ""
            array = []

            for sentence in sentences:
                match = re.search("(\d{1,2}\/\d{1,2}[\-\–]\d{1,2}|\d{1,2}\/\d{1,2}[\-\–]\d{1,2}\/\d{1,2}|\d{1,2}\/\d{1,2})", sentence)

                if match != None or re.search("lunar month",sentence):
                    if len(buffer) == 0:
                        array.append(buffer)
                        buffer = sentence
                    else:
                        array.append(buffer)
                        buffer = sentence
                else:
                    buffer = buffer + " " + sentence

            array.append(buffer)

            array = array[1:]

            entryno = 0

            for e in array:

                entryno = entryno + 1
                startdate = "MM-DD"
                enddate = "MM-DD"

                date = re.search("(\d{1,2}\/\d{1,2}[\-\–]\d{1,2}|\d{1,2}\/\d{1,2}[\-\–]\d{1,2}\/\d{1,2}|\d{1,2}\/\d{1,2})", e)
                if date != None:
                    if date.group(0).count("–") == 0:
                        alpha = re.split("/",date.group(0))
                        if len(alpha[0]) == 1:
                            alpha[0] = "0" + alpha[0]
                        if len(alpha[1]) == 1:
                            alpha[1] = "0" + alpha[1]

                        startdate = alpha[0] + "-" + alpha[1]
                        enddate = startdate

                    if date.group(0).count("/") == 2:
                        alpha = re.split("–",date.group(0))
                        bravo = re.split("/",alpha[0])
                        charlie = re.split("/",alpha[1])

                        if len(bravo[0]) == 1:
                            bravo[0] = "0" + bravo[0]
                        if len(bravo[1]) == 1:
                            bravo[1] = "0" + bravo[1]
                        if len(charlie[0]) == 1:
                            charlie[0] = "0" + charlie[0]
                        if len(charlie[1]) == 1:
                            charlie[1] = "0" + charlie[1]

                        startdate = bravo[0] + "-" + bravo[1]
                        enddate = charlie[0] + "-" + charlie[1]

                    if date.group(0).count("–") == 1 and date.group(0).count("/") == 1:
                        alpha = re.split("–",date.group(0))
                        bravo = re.split("/",alpha[0])

                        if len(bravo[0]) == 1:
                            bravo[0] = "0" + bravo[0]
                        if len(bravo[1]) == 1:
                            bravo[1] = "0" + bravo[1]
                        if len(alpha[0]) == 1:
                            alpha[0] = "0" + alpha[0]

                        startdate = bravo[0] + "-" + bravo[1]
                        enddate = bravo[0] + "-" + alpha[1]

                    gods_involved = []
                    for godEntry in goddata:

                        if godEntry["Name"] in e:
                            if not godEntry["Name"] in gods_involved:
                                gods_involved.append(godEntry["Name"])
                        else:
                            for aliases in godEntry["Aliases"]:
                                if aliases in gods_involved:
                                    if not godEntry["Name"] in gods_involved:
                                        gods_involved.append(godEntry["Name"])
                            for aliases in godEntry["Name_zh"]:
                                if aliases in gods_involved:
                                    if not godEntry["Name"] in gods_involved:
                                        gods_involved.append(godEntry["Name"])

                ritualsout.append({
                    "startdate": startdate,
                    "enddate": enddate,
                    "uid_r": entry["UID"]+"-"+str(entryno),
                    "text": e,
                    "gods_involved": gods_involved
                })

with open('./output/birthday_celebrations.json', 'w', encoding='utf8') as outfile:
    json.dump(ritualsout, outfile, ensure_ascii=False)
    
with open("./output/birthday_celebrations.csv", "w") as outfile:
    writer = csv.DictWriter(outfile, fieldnames=ritualsout[0].keys(), escapechar='\\')
    writer.writeheader()
    writer.writerows(ritualsout)

# %%
# DO NOT USE
# Proces data in a way friendly for Select2

import json, csv

output = []
    
with open('./output/Villages.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    next(spamreader, None)
    
    
    for row in spamreader:
        output.append({
            "id": row[0],
            "title": row[0] + ": "+ row[1] + " " + row[2]
        })

with open("./output/village_search.json", "w") as outfile:
    json.dump(output, outfile, ensure_ascii=False)
    outfile.close()
    
with open("./output/god_names.json") as godfile:
    goddata = json.load(godfile)
    
with open('./output/primary_gods.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    next(spamreader, None)
    
    output = []
    
    gods_buffer = {}
    
    for row in spamreader:
        if row[1] in gods_buffer:
            gods_buffer[row[1]].append(row[0][0:4])
        else: 
            gods_buffer[row[1]] = [row[0][0:4]]
                
                
    for entry in sorted(gods_buffer):
        
        name_zh = ""
        
        for god_name_entry in goddata:
            
            if god_name_entry["Name"] == entry: 
                name_zh = god_name_entry["Name_zh"]
                
        if name_zh == "":
            raise Exception("Chinese name not found for ", entry)
        
        output.append({
            "id": gods_buffer[entry],
            "title": entry + " " + name_zh
        })
        
with open("./output/primary_god_search.json", "w") as outfile:
    json.dump(output, outfile, ensure_ascii=False)

    outfile.close()

# %%
# DO NOT USE
# Process text for the calendar function

import json, csv, re

output = []
    
with open('./output/processions.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='"')
    next(spamreader, None)
    
    output=[]

    # Create array
    for i in range(1,13):
        month = str(i)
        if len(month) == 1:
            month="0"+month
        
        for i in range(1,32):
            day = str(i)
            if len(day) == 1:
                day="0"+day
            date = month + "-" + day

            output.append({
                "date": date,
                "ID": [],
                "weight": 0,
                "gods": {}
            })

    for entry in spamreader:
        
        # one-day event?
        if entry[0] == entry[1]:
            
            ## Filter out entries without dates
            if entry[0] == "MM-DD":
                continue;
            else:
                correct_entry = list(filter(lambda k: k["date"] == entry[0], output))[0]
                
            correct_entry["weight"] = correct_entry["weight"] + 1
            
        else:
            start_date = re.split("-", entry[0])
            m1 = int(start_date[0])
            d1 = int(start_date[1])
            
            end_date = re.split("-", entry[1])
            m2 = int(end_date[0])
            d2 = int(end_date[1])
            
            duration = 31 * (m2-m1) - d1 + d2 + 1
            
            if m1 == m2:
                if (len(str(m1))) == 1:
                    m1 = "0" + str(m1)
                
                for i in range (d1, d2+1):
                    d = str(i)
                    if (len(str(i))) == 1:
                        d = "0" + str(i)
                    
                    correct_entry = list(filter(lambda k: k["date"] == str(m1)+"-"+d, output))[0]
                    
                    correct_entry["weight"] = correct_entry["weight"] + (1/duration)
                    
                    correct_entry["ID"].append(entry[2])
                    
with open("./output/test.json", "w") as outfile:
    json.dump(output, outfile, ensure_ascii=False)

    outfile.close()

# %%
# DO NOT USE
# Process text for the calendar function

import json, csv, re

output = []

with open("./output/god_names.json") as godfile:
    goddata = json.load(godfile)
    
with open('./output/birthday_celebrations.json', newline='') as csvfile:
    spamreader = json.load(csvfile)

    output=[]

    # Create array
    for i in range(1,13):
        month = str(i)
        if len(month) == 1:
            month="0"+month
        
        for i in range(1,32):
            day = str(i)
            if len(day) == 1:
                day="0"+day
            date = month + "-" + day

            output.append({
                "date": date,
                "ID": [],
                "weight": 0,
                "gods": {}
            })

    for entry in spamreader:
        # one-day event?
        if entry[0] == entry[1]:
            
            ## Filter out entries without dates
            if entry[0] == "MM-DD":
                continue;
            else:
                correct_entry = list(filter(lambda k: k["date"] == entry[0], output))[0]
                
            correct_entry["weight"] = correct_entry["weight"] + 1
            
        else:
            start_date = re.split("-", entry[0])
            m1 = int(start_date[0])
            d1 = int(start_date[1])
            
            end_date = re.split("-", entry[1])
            m2 = int(end_date[0])
            d2 = int(end_date[1])
            
            duration = 31 * (m2-m1) - d1 + d2 + 1
            
            if m1 == m2:
                if (len(str(m1))) == 1:
                    m1 = "0" + str(m1)
                
                for i in range (d1, d2+1):
                    d = str(i)
                    if (len(str(i))) == 1:
                        d = "0" + str(i)
                    
                    correct_entry = list(filter(lambda k: k["date"] == str(m1)+"-"+d, output))[0]
                    
                    correct_entry["weight"] = correct_entry["weight"] + (1/duration)
                    
                    correct_entry["ID"].append(entry[2])
            
                
with open("./output/birthday_sorted.json", "w") as outfile:
    json.dump(output, outfile, ensure_ascii=False)

    outfile.close()
# Out:
# ['02-25', '02-25', 'V001-1', '2/25: The birthday celebration of Guangping Zhouwang 广平周王.', '[]']
# ['03-13', '03-13', 'V001-2', '3/13: The birthday celebration of Qianshi shengfei 钱氏圣妃.', "['Qianshi shengfei']"]
# ['07-07', '07-07', 'V001-3', '7/7: The birthday celebration of Taishan Kongwang 泰山孔王.', '[]']
# ['08-14', '08-14', 'V001-4', '8/14: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. On these days opera is performed, and Daoist ritual masters are invited to conduct rites. The village organizes the event and funds are collected on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['08-15', '08-15', 'V002-1', '8/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed, and Daoist ritual masters are invited to conduct rites. The village organizes the event and funds are collected on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-24', '06-24', 'V003-1', '6/24: The birthday celebration of Yushu dadi 玉枢大帝 is organized by the village.', "['Yushu dadi']"]
# ['08-23', '08-23', 'V003-2', '8/23: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is co-organized with the village of Tiezao 铁灶. On these occasions, opera is performed, and Daoist ritual masters are invited to conduct rites. Funds are collected on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['01-09', '01-09', 'V004-1', '1/9: The celebration of Yuhuang dadi 玉皇大帝. This event is organized by the village as a whole.', "['Yuhuang dadi']"]
# ['05-16', '05-16', 'V004-2', '5/16: The birthday celebration of Yuhuang dadi 玉皇大帝. This event is organized by the village as a whole.', "['Yuhuang dadi']"]
# ['07-16', '07-16', 'V004-3', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主. Opera is performed, and Three in One scripture masters 经师 conduct rituals. This event is organized by the village as a whole.', "['Sanyi jiaozhu']"]
# ['08-23', '08-23', 'V004-4', '8/23: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Mulan zushê 木兰祖社. This celebration is organized together with Baiyuling 白玉岭 village.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['09-29', '09-29', 'V004-5', '9/29: Another birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Mulan zhongshê 木兰中社. This event is organized by Tiezao village as a whole. On these occasions, opera is performed, and, for the most part, Daoist ritual masters are invited to conduct rites. The village organizes the event and funds are collected on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-26', '04-26', 'V005-1', '4/26: The birthday celebration of Yanggong taishi 杨公太师. The god goes on procession within the village as well as to the villages of Shanghengshan 上横山 and Xiahengshan 下横山, and Puzi 莆仔. These events are organized by Longquan Taishimiao 龙泉太师庙, and funds are collected on a per capita basis.', "['Yanggong taishi']"]
# ['06-06', '06-06', 'V005-2', '6/6: The birthday celebration of Fude zhengshen 福德正神.', "['Fude zhengshen']"]
# ['08-10', '08-10', 'V005-3', '8/10: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['08-14', '08-14', 'V005-4', '8/14: The birthday celebration of Huangfu daren 黄府大人.', "['Huangfu daren']"]
# ['12-25', '12-25', 'V005-5', '12/25: The birthday celebration of Jiucha shenghou 纠察圣候. Marionette plays are performed. On these occasions, unless otherwise specified, opera is performed, and Daoist ritual masters are invited to conduct rites. The entire village organizes the ritual together, and funds are collected on a per capita basis.', '[]']
# ['04-26', '04-26', 'V006-1', '4/26: The birthday celebration of Yanggong taishi 杨公太师. The god goes on procession within Puzi village as well as to the villages of Shanghengshan 上横山 and Xiahengshan 下横山, and Longqian 龙前. Opera is performed. These events are organized by Longquan taishimiao 龙泉太师庙, and funds are collected on a per capita basis.', "['Yanggong taishi']"]
# ['05-20', '05-20', 'V006-2', '5/20: The birthday celebration of Tiangong yuanshuai 田公元帅.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['07-16', '07-16', 'V006-3', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主.', "['Sanyi jiaozhu']"]
# ['08-23', '08-23', 'V006-4', '8/23: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. On these occasions, opera is performed, and Daoist ritual masters are invited to conduct rites. The village organizes the event and funds are collected on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-28', '03-28', 'V007-1', '3/28: The birthday celebration of Dongyue zhusheng dadi 东岳注生大帝 is organized by Xiashê 下社.', '[]']
# ['04-26', '04-26', 'V007-2', '4/26: The birthday celebration of Yanggong taishi 杨公太师. The god goes on procession within the village and to three other nearby villages. Opera is performed. These events are organized by Longquan taishimiao 龙泉太师庙, and funds are collected on a per capita basis.', "['Yanggong taishi']"]
# ['05-19', '05-19', 'V007-3', '5/19: The birthday celebration of Chenghuang laoye 城隍老爷 is organized by the village as a whole.', '[]']
# ['06-06', '06-06', 'V007-4', '6/6: The birthday celebration of Fude zhengsheng 福德正神 is organized by Xipai 西牌.', "['Fude zhengshen']"]
# ['08-18', '08-18', 'V007-5', '8/18: The birthday celebration of Cuifu dama 崔府大妈 is organized by Shangshê 上社.', "['Cuifu dama']"]
# ['10-20', '10-20', 'V007-6', '10/20: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人is organized by the village as a whole. On these occasions, opera is performed, and Daoist ritual masters are invited to conduct rites. Funds are collected on a per capita basis by the village as a whole, or by the neighborhood organizing the event.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-26', '04-26', 'V008-1', '4/26: The birthday celebration of Yanggong taishi 杨公太师. The god is taken on a procession within the village as well as to the villages of Shanghengshan 上横山, Puzi 莆仔 and Longqian 龙前. Opera is performed, and Daoist ritual masters are invited to conduct rituals. These events are organized by Longqian taishimiao 龙前太师庙, and funds are collected on a per capita basis.', "['Yanggong taishi']"]
# ['05-21', '05-21', 'V008-2', '5/21: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人is organized by the village as a whole.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-07', '07-07', 'V008-3', '7/7: The birthday celebration of Lufu furen 鲁府夫人 is organized by Ciyundong 慈云洞.', "['Lufu furen']"]
# ['07-16', '07-16', 'V008-4', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主 is organized by the village as a whole.', "['Sanyi jiaozhu']"]
# ['08-15', '08-15', 'V008-5', '8/15: The birthday celebration of Cuifu dama 崔府大妈 is organized by Dongshanfu 东山府.', "['Cuifu dama']"]
# ['09-09', '09-09', 'V008-6', '9/9: The birthday celebration of Dutian yuanshuai 都天元帅 is organized by the village as a whole. On these occasions, opera is performed, and Daoist ritual masters are invited to conduct rites. The village or the temple and its community organizes the event and funds are collected on a per capita basis.', "['Dutian yuanshuai']"]
# ['03-13', '03-4', 'V009-1', '3/13–4/16: The birthday celebration of Qianshi shengfei 钱氏圣妃. Opera is performed for four days. This event is organized by the village as a whole.', "['Qianshi shengfei']"]
# ['06-15', '06-15', 'V009-2', '6/15: The birthday celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Guolongshê 郭陇社 is organized by the Wang 王. Marionette plays are performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-19', '07-21', 'V009-3', '7/19–21: The Chen 陈 organize a pilgrimage to Xiangshangong 香山宫 to invite the goddess Qianshi shengfe 钱氏圣妃 back to the village to watch opera.', '[]']
# ['08-15', '08-15', 'V009-4', '8/15: The birthday celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Xiyuanshê 西园社 is organized by the Zhang 张. Marionette plays are performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-23', '03-23', 'V010-1', '3/23: The birthday celebration of Tianshang shengmu 天上圣母.', "['Tianshang shengmu']"]
# ['04-14', '04-14', 'V010-2', '4/14: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V010-3', '7/23: The birthday celebrations for Zhanggong shengjun 张公圣君. Marionette plays are performed. All these events are organized by the village itself, and funds are collected on a per capita basis. Opera is usually performed, and Daoist rites are held.', "['Zhanggong shengjun']"]
# ['03-16', '03-4', 'V011-1', '3/16–4/16: The birthday celebration of Qianshi shengfei 钱氏圣妃. A procession is made to Xiangshangong 香山宫 to carry the goddess back to the village to watch the opera.', "['Qianshi shengfei']"]
# ['06-19', '06-19', 'V011-2', '6/19: The birthday celebration of Guanyin dashi 观音大士. Marionette plays are performed.', "['Guanyin', 'Guanyin dashi']"]
# ['08-15', '08-15', 'V011-3', '8/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held 8/23: The birthday celebration of Tiangong yuanshuai 田公元帅.', "['Houtu furen', 'Tiangong', 'Tiangong yuanshuai', 'Zunzhu mingwang']"]
# ['09-16', '09-16', 'V011-4', '9/16: The birthday celebration of Sanyi jiaozhu 三一教主 and Wushi xiansheng 吴氏先生 is organized by the Mingdetang 明德堂. Marionette plays are performed. On the larger ritual occasions, opera is performed and Daoist rites are held.', "['Sanyi jiaozhu', 'Wushi xiansheng']"]
# ['05-13', '05-13', 'V012-1', '5/13: The birthday celebration of Sima shengwang 司马圣王. Opera is performed for three days.', "['Sima shengwang']"]
# ['08-01', '08-01', 'V012-2', '8/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed for two days.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-02', '05-02', 'V013-1', '5/2: The birthday celebration of Qianshi shengfei 钱氏圣妃 is held with opera.', "['Qianshi shengfei']"]
# ['08-15', '08-15', 'V013-2', '8/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-28', '03-28', 'V014-1', '3/28: The birthday celebration of Zhusheng dadi 注生大帝. Opera is performed and Daoist ritual masters perform rites.', "['Zhusheng dadi']"]
# ['04-15', '04-15', 'V014-2', '4/15: The birthday celebration of Caofu jiangjun 曹府将军. Opera is performed.', '[]']
# ['09-16', '09-16', 'V014-3', '9/16: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-23', '03-23', 'V015-1', '3/23: The birthday celebration of Tianshang shengmu 天上圣母 is held. Opera is performed and Daoist ritual masters conduct rites.', "['Tianshang shengmu']"]
# ['09-01', '09-01', 'V015-2', '9/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen is held. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-28', '03-28', 'V016-1', '3/28: The birthday celebration of Zhusheng dadi 注生大帝.', "['Zhusheng dadi']"]
# ['05-26', '05-26', 'V016-2', '5/26: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['02-17', '02-17', 'V017-1', '2/17: The birthday celebration of Chen Wenlong 陈文龙.', "['Chen Wenlong']"]
# ['05-19', '05-19', 'V017-2', '5/19: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-06', '06-06', 'V017-3', '6/6: The birthday celebration of Fude zhengshen 福德正神.', "['Fude zhengshen']"]
# ['06-06', '06-06', 'V017-4', 'Note: the sevenfold ritual alliance of Zhengban hosts a grand birthday celebration of Tudigong 土地公 on 6/6. There are ten days of opera and seven days of movies.', "['Tudigong']"]
# ['10-29', '10-29', 'V017-5', '10/29: Laishuiting 来水亭 hosts the Lanpen pudu 兰盆普度 rites of Universal Deliverance every year. Marionette plays are performed.', '[]']
# ['05-15', '05-15', 'V018-1', '5/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['09-15', '09-15', 'V018-2', '9/15: The birthday celebration of Tiangong yuanshuai 田公元帅. Opera is performed.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['03-28', '03-28', 'V019-1', '3/28: The birthday celebration of Dongyue zhusheng dadi 东岳注生大帝 is held with opera performances.', '[]']
# ['05-19', '05-19', 'V019-2', '5/19: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held with opera performances.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-08', '06-08', 'V020-1', '6/8: The celebration of Xu daren 徐大人 is held with opera performances.', "['Xu daren']"]
# ['03-18', '03-18', 'V021-1', '3/18: Birthday celebration of Zhusheng dadi 注生大帝. Opera is performed.', "['Zhusheng dadi']"]
# ['05-19', '05-19', 'V021-2', '5/19: Birthday celebration of Zunzhu mingwang 尊主明王, Houtu furen 后土夫人. Opera performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['08-04', '08-04', 'V022-1', '8/4: Birthday celebration of Zunzhu mingwang 尊主明王, Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-19', '05-19', 'V023-1', '5/19: Birthday celebration of Zunzhu mingwang 尊主明王, Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-12', '03-12', 'V024-1', '3/12: The birthday celebration of Taiyi xiangu 太乙仙姑.', "['Taiyi xiangu']"]
# ['03-13', '03-13', 'V024-2', '3/13: The birthday celebration of Qianshi shengfei 钱氏圣妃.', "['Qianshi shengfei']"]
# ['03-15', '03-15', 'V024-3', '3/15: The birthday celebration of Wengong yuanshuai 温公元帅.', '[]']
# ['06-01', '06-01', 'V024-4', '6/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V024-5', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君. (Opera is performed according to neighborhoods. Each time, opera is performed for two days.)', "['Zhanggong shengjun']"]
# ['03-13', '03-13', 'V025-1', '3/13: The birthday celebration of Qianshi shengfei 钱氏仙妃.', "['Qianshi shengfei']"]
# ['06-15', '06-15', 'V025-2', '6/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V025-3', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君. Every year, opera is performed twice in the village. Zhu Guangdi 朱光地, a Singaporean Chinese, donated the funds to cover the cost of the performances and the construction of the stage. 60–70% of the villagers believe in Christianity. A Christian fellowship is currently being organized.', "['Zhanggong shengjun']"]
# ['03-03', '03-03', 'V026-1', '3/3: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土 夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-09', '03-09', 'V026-2', '3/9: The celebration of Huanggong ershi 黄公二使.', "['Huanggong', 'Huanggong ershi']"]
# ['10-18', '10-18', 'V026-3', '10/18: The celebration of Kongfu daren 孔府大人. On all these occasions, opera is performed and Daoist ritual masters may be invited to conduct rites. These events are organized by the village as a whole, and funds are raised on a per capita basis.', "['Kongfu daren']"]
# ['03-03', '03-03', 'V027-1', '3/3: The celebration of Xuantian shangdi 玄天上帝.', "['Xuantian shangdi']"]
# ['04-11', '04-11', 'V027-2', '4/11: The celebration of Cigan shengfei 慈感圣妃.', '[]']
# ['05-18', '05-18', 'V027-3', '5/18: The celebration of Wang Lingguan 王灵官. Marionette plays are performed.', '[]']
# ['06-01', '06-01', 'V027-4', '6/1: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-18', '10-18', 'V027-5', '10/18: The celebration of Kongfu daren 孔府大人.', "['Kongfu daren']"]
# ['02-25', '02-25', 'V028-1', '2/25: The celebration of Qitian dasheng 齐天大圣 is organized by the Chen 陈.', "['Qitian dasheng']"]
# ['03-01', '03-01', 'V028-2', '3/1: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is organized by the village as a whole.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-28', '03-28', 'V028-3', '3/28: The celebration of Zhusheng dadi 注生大帝 is organized by the 陈. The celebration of Cigan xianfe 慈感仙妃 is organized by the Qiu 邱. The celebration of Guanyin dashi 观音大士 is organized by the village as a whole.', "['Guanyin', 'Guanyin dashi', 'Zhusheng dadi']"]
# ['09-09', '09-09', 'V028-4', '9/9: The celebration of Dutian yuanshuai 都天元帅 is organized by the Qiu 邱.', "['Dutian yuanshuai']"]
# ['10-18', '10-18', 'V028-5', '10/18: The celebration of Kongfu daren 孔府大人 is organized by the village as a whole. On all these occasions, opera is performed and Daoist ritual masters may be invited to conduct rites. Funding is raised on a per capita basis by the organizing group, whether it be the village as a whole, or a particular lineage group.', "['Kongfu daren']"]
# ['04-12', '04-12', 'V028-6', '4/12: 6/19:', '[]']
# ['11-01', '11-01', 'V029-1', '11/1: The birthday celebration of Liugong yuanshuai 刘公元帅.', "['Liugong yuanshuai']"]
# ['10-29', '10-29', 'V029-2', '10/29: Jihuci 集壶祠 holds the Lanpen pudu 兰盆普度 rites of Universal Deliverance.', '[]']
# ['03-13', '03-13', 'V030-1', '3/13: The birthday celebration of Qianshi shengfei 钱氏圣妃. Opera is performed.', "['Qianshi shengfei']"]
# ['11-01', '11-01', 'V030-2', '11/1: The birthday celebration of Liugong yuanshuai 刘公元帅. Opera is performed.', "['Liugong yuanshuai']"]
# ['03-13', '03-13', 'V031-1', '3/13: The birthday celebration of Qianshi shengfei 钱氏圣妃.', "['Qianshi shengfei']"]
# ['03-23', '03-23', 'V031-2', '3/23: The birthday celebration of Tianshang shengmu 天上圣母.', "['Tianshang shengmu']"]
# ['04-26', '04-26', 'V031-3', '4/26: The birthday celebration of Yanggong taishi 杨公太师.', "['Yanggong taishi']"]
# ['06-19', '06-19', 'V031-4', '6/19: The birthday celebration of Guanyin dashi 观音大士.', "['Guanyin', 'Guanyin dashi']"]
# ['07-01', '07-01', 'V031-5', '7/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V031-6', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君. This event is held with Dubian 度边 and Tangbian 塘边 villages. On these occasions, opera is performed, and in some cases Daoist ritual masters are invited to conduct rites. These events are organized by the village as a whole, and funding is raised on a per capita basis.', "['Zhanggong shengjun']"]
# ['05-05', '05-05', 'V032-1', '5/5: The birthday celebration of Wuhuang dadi 五皇大帝 is held.', "['Wuhuang dadi']"]
# ['04-26', '04-26', 'V033-1', '4/26: The birthday celebration of Yanggong taishi 杨公太师.', "['Yanggong taishi']"]
# ['07-23', '07-23', 'V033-2', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君. This is held together with Dongling 东岭 and Tangbian 塘边.', "['Zhanggong shengjun']"]
# ['09-12', '09-12', 'V033-3', '9/12: The birthday celebration of the Wuxiong 五兄. Opera is performed for over ten days.', "['Wuxiong']"]
# ['05-05', '05-05', 'V034-1', '5/5: The birthday celebration of Wuhuang dadi 五皇大帝.', "['Wuhuang dadi']"]
# ['09-09', '09-09', 'V034-2', '9/9: The birthday celebration of Dutian yuanshuai 都天元帅.', "['Dutian yuanshuai']"]
# ['06-18', '06-18', 'V035-1', '6/18: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['08-23', '08-23', 'V035-2', '8/23: The birthday celebration of Tiangong yuanshuai 田公元帅. Marionette plays are performed.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['09-12', '09-12', 'V035-3', '9/12: The birthday celebration of Xufu daren 徐府大人.', '[]']
# ['03-23', '03-23', 'V036-1', '3/23: The birthday celebration of Tianshang shengmu 天上圣母. Opera is performed, and Daoist ritual masters are invited to conduct rituals.', "['Tianshang shengmu']"]
# ['07-16', '07-16', 'V036-2', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主. Marionette plays are performed.', "['Sanyi jiaozhu']"]
# ['09-01', '09-01', 'V036-3', '9/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed, and Daoist ritual masters are invited to conduct rituals.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-23', '03-23', 'V037-1', '3/23: The birthday celebration of Tianshang shengmu 天上圣母.', "['Tianshang shengmu']"]
# ['04-16', '04-16', 'V037-2', '4/16: The birthday celebration of Jinfu daren 金府大人.', "['Jinfu daren']"]
# ['05-13', '05-13', 'V037-3', '5/13: The birthday celebration of Sima shengwang 司马圣王. Marionette plays are performed.', "['Sima shengwang']"]
# ['06-06', '06-06', 'V037-4', '6/6: The birthday celebration of Fude zhengshen 福德正神.', "['Fude zhengshen']"]
# ['06-19', '06-19', 'V037-5', '6/19: The birthday celebration of Guanyin dashi 观音大士.', "['Guanyin', 'Guanyin dashi']"]
# ['07-01', '07-01', 'V037-6', '7/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['08-23', '08-23', 'V037-7', '8/23: The birthday celebration of Tiangong yuanshuai 田公元帅.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['09-09', '09-09', 'V037-8', '9/9: The birthday celebration of Taiyi xiangu 太乙仙姑.', "['Taiyi xiangu']"]
# ['11-22', '11-22', 'V037-9', '11/22: The birthday celebration of Zhenggong dutong 郑公都统.', "['Zhenggong dutong']"]
# ['MM-DD', 'MM-DD', 'V037-10', 'In the 10th lunar month, on a day determined by divination the birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Gonglin zushê 拱林祖社 is held. Opera is performed, and Daoist ritual masters are invited to conduct rituals. These events are organized by the threefold village ritual alliance, and funds are collected on a per capita basis.', "['Zhenggong dutong']"]
# ['11-22', '11-22', 'V037-11', '11/22: The birthday celebration of Zhenggong dutong 郑公都统. On most of these occasions opera is performed, and Daoist ritual masters are invited to conduct rituals. These events are organized primarily by the village as a whole, and funds are collected on a per capita basis.', "['Zhenggong dutong']"]
# ['04-09', '04-09', 'V038-1', '4/9: The birthday celebration of Tiangong yuanshuai 田公元帅. Opera is performed for three days.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['04-12', '04-12', 'V038-2', '4/12: The birthday celebration of Cigan xianfei 慈感仙妃. Opera is performed.', "['Cigan xianfei']"]
# ['07-01', '07-01', 'V038-3', '7/1: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['11-01', '11-01', 'V038-4', '11/1: The birthday celebration of Liugong yuanshuai 刘公元帅. On all these occasions, opera is performed and Daoist ritual masters may be invited to conduct rites. The village organizes these events as a whole, and funds are raised on a per capita basis.', "['Liugong yuanshuai']"]
# ['04-09', '04-09', 'V039-1', '4/9: The birthday celebration of Tiangong yuanshuai 田公元帅.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['05-16', '05-16', 'V039-2', '5/16: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-19', '06-19', 'V039-3', '6/19: The birthday celebration of Guanyin dashi 观音大士.', "['Guanyin', 'Guanyin dashi']"]
# ['07-16', '07-16', 'V039-4', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主.', "['Sanyi jiaozhu']"]
# ['07-23', '07-23', 'V039-5', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君.', "['Zhanggong shengjun']"]
# ['08-23', '08-23', 'V039-6', '8/23: The birthday celebration of Tiangong yuanshuai 田公元帅. On all these occasions, opera is performed and Daoist ritual masters are sometimes invited to conduct rites. Funding is raised on a per capita basis by the village as a whole.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['02-25', '02-25', 'V040-1', '2/25: The birthday celebration of Qitian dasheng 齐天大圣 is organized by Xiaqiao 下桥.', "['Qitian dasheng']"]
# ['03-14', '03-14', 'V040-2', '3/14: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Shaoxing lishê 绍兴里社 is organized by Xiaqiao 下桥.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-15', '03-15', 'V040-3', '3/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Longxing shangshê 隆兴上社is organized by Dingqiao 顶桥.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-15', '04-15', 'V040-4', '4/15: The birthday celebration of Sanyi jiaozhu 三一教主 is organized by Dingqiao 顶桥.', "['Sanyi jiaozhu']"]
# ['05-05', '05-05', 'V040-5', '5/5: The birthday celebration of Wuhuang dadi 五皇大帝 is organized by Dingqiao 顶桥. On these occasions, opera is performed and Daoist rites are held. The village as a whole, or a particular temple and it’s community or lineage group organizes the event. Funds are collected on a per capita basis.', "['Wuhuang dadi']"]
# ['05-15', '05-15', 'V041-1', '5/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V041-2', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君.', "['Zhanggong shengjun']"]
# ['10-18', '10-18', 'V041-3', '10/18: The birthday celebration of Kongfu daren 孔府大人. On these occasions, opera is performed, and Daoist ritual masters are invited to conduct rites. The village organizes the event and funds are collected on a per capita basis.', "['Kongfu daren']"]
# ['04-08', '04-08', 'V042-1', '4/8: The birthday celebration of Huangdu yuanshuai 黄都元帅.', '[]']
# ['07-16', '07-16', 'V042-2', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主 is organized by the Guilinci 桂林祠.', "['Sanyi jiaozhu']"]
# ['08-03', '08-03', 'V042-3', '8/3: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['08-23', '08-23', 'V042-4', '8/23: The birthday celebration of Tiangong yuanshuai 田公元帅. On these occasions, opera is performed, and Daoist ritual masters are invited to conduct rites. The village organizes the event (unless otherwise specified) and funds are collected on a per capita basis.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['03-16', '03-16', 'V043-1', '3/16: The birthday celebration of Xuantan yuanshuai 玄坛元帅. Opera is performed.', "['Xuantan yuanshuai']"]
# ['06-24', '06-24', 'V043-2', '6/24: The birthday celebration of Puhua tianzun 普化天尊. Opera is performed.', "['Puhua tianzun']"]
# ['06-29', '06-29', 'V043-3', '6/29: The birthday celebration of Chensheng faye 陈胜法爷. Opera is performed.', "['Chensheng faye']"]
# ['08-15', '08-15', 'V043-4', '8/15: The birthday celebration of Jialuo dasheng 伽罗大圣. Opera is performed, and Daoist ritual masters are invited to conduct rites.', "['Jialuo dasheng']"]
# ['08-23', '08-23', 'V043-5', '8/23: The birthday celebration of Tiangong yuanshuai 田公元帅. Opera is performed.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['10-16', '10-16', 'V043-6', '10/16: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed, and Daoist ritual masters are invited to conduct rites.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['11-27', '11-27', 'V043-7', '11/27: The birthday celebration of Daxiong 大兄. Opera is performed, and Daoist ritual masters are invited to conduct rites. On all these occasions, the village as a whole organizes the event and funds are collected on a per capita basis.', "['Daxiong']"]
# ['03-08', '03-08', 'V044-1', '3/8: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-05', '05-05', 'V044-2', '5/5: The birthday celebration of Lufu dashen 鲁府大神.', '[]']
# ['07-23', '07-23', 'V044-3', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君.', "['Zhanggong shengjun']"]
# ['10-18', '10-18', 'V044-4', '10/18: The birthday celebration of Kongfu daren 孔府大人.', "['Kongfu daren']"]
# ['05-01', '05-3', 'V045-1', '5/1–3: the celebration of Sanwei zhenjun 三位真君 is held with opera.', '[]']
# ['07-19', '07-20', 'V045-2', '7/19–20: The birthday celebration of Zhanggong shengjun 张公圣君 of the Dejitang 德济堂. The god is invited to watch opera.', "['Zhanggong shengjun']"]
# ['08-01', '08-01', 'V045-3', '8/1: The celebration of Qianshi shengfei 钱氏圣妃 is held with opera.', "['Qianshi shengfei']"]
# ['10-11', '10-11', 'V045-4', '10/11: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-26', '03-26', 'V046-1', '3/26: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held with opera, in rotation with Houshê 后社 village.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-18', '07-18', 'V046-2', '7/18: The birthday celebration of Zhanggong shengjun 张公圣君 is held with opera.', "['Zhanggong shengjun']"]
# ['03-26', '03-26', 'V047-1', '3/26: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is organized in rotation with Houdai 后埭, Yuanding 园顶, and Qubian 屈边 villages.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-16', '07-16', 'V047-2', '7/16: The birthday celebration of Sanyijiao 三一教主 is organized in rotation with Houdai 后埭, Yuanding 园顶, and Qubian 屈边.', '[]']
# ['09-09', '09-09', 'V047-3', '9/9: The birthday celebration of Dutian yuanshuai 都天元帅 is held with opera.', "['Dutian yuanshuai']"]
# ['03-26', '03-26', 'V048-1', '3/26: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is organized in rotation with Yuanding 园顶.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-13', '05-13', 'V048-2', '5/13: The celebration of Xietian dadi 协天大帝 is held with opera. This event is co-organized and co-sponsored (on a per capita basis) with Yuanding 园顶 village.', "['Xietian dadi']"]
# ['03-10', '03-10', 'V049-1', '3/10: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Marionette plays are performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-01', '10-01', 'V049-2', '10/1: The birthday celebration of Cuifu dama 崔府大妈 is held with two days of opera.', "['Cuifu dama']"]
# ['03-10', '03-10', 'V050-1', '3/10: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-23', '03-23', 'V050-2', '3/23: The birthday celebration of Tianhou shengmu 天后圣母. Marionette plays are performed.', "['Tianhou shengmu']"]
# ['07-23', '07-23', 'V050-3', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君. The god is invited from the Dejitang 德济堂 to watch opera in the village.', "['Zhanggong shengjun']"]
# ['08-19', '08-19', 'V050-4', '8/19: The birthday celebration of Jialuo dasheng 伽罗大圣.', "['Jialuo dasheng']"]
# ['04-26', '04-26', 'V051-1', '4/26: The celebration of Yanggong taishi 杨公太师 is held with opera performances.', "['Yanggong taishi']"]
# ['08-03', '08-03', 'V051-2', '8/3: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Qiannan Zhoushê 前南周社 is held with opera performances.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-10', '04-10', 'V052-1', '4/10: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Qiandong shushê 前东书社 is held with opera performances.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-06', '06-06', 'V052-2', '6/6: The celebration of Fude zhengshen 福德正神 is held with opera performances.', "['Fude zhengshen']"]
# ['08-09', '08-09', 'V053-1', '8/9: The celebration of Huangdu yuanshuai 黄都元帅 is held with opera 演戏.', '[]']
# ['10-12', '10-12', 'V053-2', '10/12: The celebration of the birthday of the Zunzhu mingwang 尊主明王 and 后土夫人of the Qiannan Pengshê 前南彭社 is held with opera 演戏.', "['Zunzhu mingwang']"]
# ['10-12', '10-12', 'V054-1', '10/12: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Qiannan Pengshê 前南彭社 is held with performances of opera.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['09-03', '09-03', 'V055-1', '9/3: The villagers invite Yanggong taishi 杨公太师 from the Baoquanyuan 宝泉院 to watch opera.', "['Yanggong taishi']"]
# ['09-16', '09-16', 'V055-2', '9/16: The celebration of the birthday of the Zunzhu mingwang 尊主 明王 and Houtu furen 后土夫人 of the Qiandong zushê 前东祖社 is held.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-16', '03-16', 'V056-1', '3/16: The celebration of Xuantian shangdi 玄天上帝 is held.', "['Xuantian shangdi']"]
# ['05-05', '05-05', 'V056-2', '5/5: The celebration of Lufu dashen 鲁府大神 is held.', '[]']
# ['08-23', '08-23', 'V056-3', '8/23: The celebration of Tiangong yuanshuai 田公元帅 is held. On each of these occasions, opera is performed for two days, and funds are raised on a per capita basis.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['04-26', '04-26', 'V057-1', '4/26: The celebration of Yanggong taishi 杨公太师 is held with opera.', "['Yanggong taishi']"]
# ['06-12', '06-12', 'V057-2', '6/12: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Zhangjiang qianbeishê 章江前北社 is held with opera.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-20', '06-20', 'V058-1', '6/20: the celebration of Cuifu dama 崔府大妈 is held with opera.', "['Cuifu dama']"]
# ['04-26', '04-26', 'V059-1', '4/26: The birthday celebration of Yanggong taishi 杨公太师 is organized by the village as a whole. Opera is performed.', "['Yanggong taishi']"]
# ['05-05', '05-05', 'V059-2', '5/5: The birthday celebration of Lufu dashen 鲁府大神 is held with marionette plays, and is organized by the Weng 翁, the Chen 陈 and the Xu 徐.', '[]']
# ['05-13', '05-13', 'V059-3', '5/13: The birthday celebration of Sima shengwang 司马圣王 is organized by the village as a whole. Opera is performed.', "['Sima shengwang']"]
# ['07-16', '07-16', 'V059-4', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主 is held with marionette plays, and is organized by the Weng 翁, the Chen 陈 and the Xu 徐.', "['Sanyi jiaozhu']"]
# ['08-23', '08-23', 'V059-5', '8/23: The birthday celebration of Tiangong yuanshuai 田公元帅 is organized by the village as a whole. Opera is performed.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['10-12', '10-12', 'V059-6', '10/12: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is organized by the village as a whole. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-02', '05-02', 'V060-1', '5/2: The birthday celebration of Wenchang dijun 文昌帝君 is organized by the Jukui shuyuan 聚奎书院.', "['Wenchang dijun']"]
# ['05-13', '05-13', 'V060-2', '5/13: The birthday celebration of Sima shengwang 司马圣王.', "['Sima shengwang']"]
# ['07-16', '07-16', 'V060-3', '7/16: The birthday celebration of Sanyi jiaozhu 三一教主 is held with marionette plays, and is organized by the Yuetangci 月塘祠.', "['Sanyi jiaozhu']"]
# ['10-01', '10-01', 'V060-4', '10/1: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Yongtan dongshê 涌坛东社 and the Yongtan tangshê 涌坛汤社 is held with opera performances. This event is organized by the Lin 林 and the Tang 汤.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-15', '10-15', 'V060-5', '10/15: The pudu 普度 rites of Universal Deliverance are organized by the Zunkongtang 尊孔堂.', '[]']
# ['10-18', '10-18', 'V060-6', '10/18: The celebration of Kongfu daren 孔府大人 is held with opera, and is organized by the Wanlinggong 万灵宫.', "['Kongfu daren']"]
# ['11-10', '11-10', 'V060-7', '11/10: The birthday of Zunzhu mingwang 尊主明王 and Houtu furen 后土 夫人 is held with opera performances, and is organized by the Wu 吴, the Huang 黄 and the Zheng 郑.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['11-15', '11-15', 'V060-8', '11/15: Pudu rites of Universal Deliverance 普度 are organized by Yuetangci 月塘祠.', '[]']
# ['03-03', '03-03', 'V061-1', '3/3: The birthday celebration of Xuantian shangdi 玄天上帝 is held with opera, and is organized by the Ruiyundian 瑞云殿.', "['Xuantian shangdi']"]
# ['04-15', '04-15', 'V061-2', '4/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held with opera performances organized by the Yongtan wenshê 涌坛文社.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-18', '04-18', 'V061-3', '4/18: The celebration of Huang erdaxiong 黄二大兄 is held with operas organized by Wanfutang 万福堂.', '[]']
# ['07-23', '07-23', 'V061-4', '7/23: The celebration of Zhanggong shengjun 张公圣君 is held with operas organized by the Yongtan wenshê 涌坛文社.', "['Zhanggong shengjun']"]
# ['08-18', '08-18', 'V061-5', '8/18: The celebration of Chenfu daren 陈府大人 is held with operas organized by the Wanfutang 万福堂.', "['Chenfu daren']"]
# ['02-12', '02-12', 'V062-1', '2/12: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Xingxian xinshê 兴贤新社 is organized by the Zou 邹 with opera performances.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-23', '03-23', 'V062-2', '3/23: The celebration of Tianshang shengmu 天上圣母 is organized by the village as a whole with opera performances.', "['Tianshang shengmu']"]
# ['05-05', '05-05', 'V062-3', '5/5: The celebration of Lufu dashen 鲁府大神 is organized by the village as a whole with opera performances.', '[]']
# ['07-07', '07-07', 'V062-4', '7/7: The celebration of Lufu furen 鲁府夫人 is organized by the village as a whole with opera performances.', "['Lufu furen']"]
# ['07-08', '07-08', 'V062-5', '7/8: The celebration of Kanggong yuanshuai 康公元帅 is organized by the Zou 邹 with opera performances.', "['Kanggong yuanshuai']"]
# ['10-11', '10-11', 'V062-6', '10/11: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Wanan xueshê 万安学社 is organized by the Huang 黄 and the Hu 胡.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['11-10', '11-10', 'V062-7', '11/10: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Xingxian zushê 兴贤祖社 is organized by the Zhou 周, the Chen 陈 and the Huang 黄.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['01-14', '01-14', 'V063-1', '1/14: The celebration of Sanyi jiaozhu 三一教主 is organized by the Zongxiatang 宗夏堂. Marionette plays are performed.', "['Sanyi jiaozhu']"]
# ['02-16', '02-16', 'V063-2', '2/16: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Longjin zushê 龙津祖社 is held. Opera is performed for two days.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['MM-DD', 'MM-DD', 'V063-3', 'During the 3rd lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Chunxing dongshê 淳兴东社, Chunxing nanshê 淳兴南社 and Longjin xishê 龙津 西社 is held. Opera is performed for two days.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-26', '04-26', 'V063-4', '4/26: The celebration of Yanggong taishi 杨公太师 is held. Opera is performed for two days.', "['Yanggong taishi']"]
# ['09-09', '09-09', 'V063-5', '9/9: The celebration of Yang jiuniang 杨九娘 is held. Opera is performed for two days.', "['Yang jiuniang']"]
# ['10-28', '10-28', 'V063-6', '10/28: The rites of Universal Deliverance of the Lower Prime Xiayuan pudu 下元普度 are held, organized by the Xingxiatang 行夏堂. Opera is performed for two days.', '[]']
# ['03-03', '03-03', 'V064-1', '3/3: The celebration of Xuanyuan shangdi 玄元上帝. Opera is performed five times over three days.', '[]']
# ['03-16', '03-16', 'V064-2', '3/16: The celebration of Xuantan yuanshuai 玄坛元帅 is held with opera.', "['Xuantan yuanshuai']"]
# ['MM-DD', 'MM-DD', 'V064-3', 'In the 4th lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', "['Xuantan yuanshuai']"]
# ['05-16', '05-16', 'V064-4', '5/16: The celebration of Yuhuang dadi 玉皇大帝 is held. Opera is performed five times over three days.', "['Yuhuang dadi']"]
# ['08-15', '08-15', 'V064-5', '8/15: The celebration of Wengong yuanshuai 温公元帅 is held with opera.', '[]']
# ['08-21', '08-21', 'V064-6', '8/21: The celebration of Tiangong yuanshuai 田公元帅 is held with opera.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['03-03', '03-03', 'V065-1', '3/3: The celebration of Xuanyuan shangdi 玄元上帝 is held. Opera is performed five times over three days.', '[]']
# ['03-08', '03-08', 'V065-2', '3/8: The celebration of Daxiong 大兄 is held. Marionette opera is performed.', "['Daxiong']"]
# ['MM-DD', 'MM-DD', 'V065-3', 'In the 4th lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', "['Daxiong']"]
# ['05-16', '05-16', 'V065-4', '5/16: The celebration of Yuhuang dadi 玉皇大帝 is held. Opera is performed five times over three days.', "['Yuhuang dadi']"]
# ['07-07', '07-07', 'V065-5', '7/7: The celebration of Lufu furen 鲁府夫人 is held.', "['Lufu furen']"]
# ['03-03', '03-03', 'V066-1', '3/3: The celebration of Xuanyuan shangdi 玄元上帝 is held. Opera is performed five times over three days.', '[]']
# ['04-01', '04-01', 'V066-2', '4/1: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-16', '05-16', 'V066-3', '5/16: The celebration of Yuhuang dadi 玉皇大帝 is held. Opera is performed five times over three days.', "['Yuhuang dadi']"]
# ['07-23', '07-23', 'V066-4', '7/23: The celebration for Zhanggong shengjun 张公圣君 is held with opera.', "['Zhanggong shengjun']"]
# ['08-23', '08-23', 'V066-5', '8/23: The celebration of Tiangong yuanshuai 田公元帅 is held with opera.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['10-29', '10-29', 'V066-6', '10/29: The celebration of Daxiong 大兄 is held with opera.', "['Daxiong']"]
# ['03-03', '03-03', 'V067-1', '3/3: The birthday celebration of Xuanyuan shangdi 玄元上帝. Opera is performed five times over three days.', '[]']
# ['04-11', '04-11', 'V067-2', '4/11: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['05-16', '05-16', 'V067-3', '5/16: The birthday celebration of Yuhuang dadi 玉皇大帝. Opera is performed five times over three days.', "['Yuhuang dadi']"]
# ['06-06', '06-06', 'V067-4', '6/6: The birthday celebration of Fude zhengshen 福德正神 is held with opera.', "['Fude zhengshen']"]
# ['MM-DD', 'MM-DD', 'V068-1', 'In the 4th lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', "['Fude zhengshen']"]
# ['06-19', '06-19', 'V068-2', '6/19: The celebration of Guanyin dashi 观音大士 is held with operas.', "['Guanyin', 'Guanyin dashi']"]
# ['07-23', '07-23', 'V068-3', '7/23: The celebration of Zhanggong shengjun 张公圣君 is held with operas.', "['Zhanggong shengjun']"]
# ['MM-DD', 'MM-DD', 'V069-1', 'In the 4th lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', "['Zhanggong shengjun']"]
# ['07-16', '07-16', 'V069-2', '7/16: The celebration of Sanyi jiaozhu 三一教主 is held with operas. This event is co-sponsored by Peiwei 沛尾 village.', "['Sanyi jiaozhu']"]
# ['03-03', '03-03', 'V070-1', '3/3: The birthday celebration of Xuanyuan shangdi 玄元上帝 is held with operas.', '[]']
# ['MM-DD', 'MM-DD', 'V070-2', 'In the 4th lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', '[]']
# ['MM-DD', 'MM-DD', 'V071-1', 'In the 4th lunar month, on a day determined by divination, the celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held.', '[]']
# ['04-09', '04-09', 'V071-2', '4/9: The celebration of Tiangong yuanshuai 田公元帅 is held with operas.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['06-06', '06-06', 'V071-3', '6/6: The celebration of Fude zhengshen 福德正神 is held with operas.', "['Fude zhengshen']"]
# ['02-27', '02-27', 'V072-1', '2/27: The birthday celebration of Daye 大爷 is organized by the village as a whole. Opera is performed and Daoist ritual masters are invited to conduct rites. Funding is gathered on a per capita basis.', "['Daye']"]
# ['03-10', '03-10', 'V072-2', '3/10: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Baofu shushê 保福书社 is organized by the Li 李.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-22', '10-22', 'V072-3', 'Opera is performed 10/22: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Wanan dongshê 万安东社 is organized by the Yang 杨. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-03', '03-03', 'V073-1', '3/3: The celebration of Xuantian shangdi 玄天上帝 is held with opera.', "['Xuantian shangdi']"]
# ['04-13', '04-13', 'V073-2', '4/13: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Baofu shushê 保福书社 is held with opera.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-06', '06-06', 'V073-3', '6/6: The celebration of Fude zhengshen 福德正神 is held with opera.', "['Fude zhengshen']"]
# ['03-03', '03-03', 'V074-1', '3/3: The birthday celebration of Xuantian shangdi 玄天上帝. Opera is performed.', "['Xuantian shangdi']"]
# ['10-15', '10-15', 'V074-2', '10/15: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-27', '03-27', 'V075-1', '3/27: The celebration of Tianshang shengmu 天上圣母 is organized by the village as a whole. Opera is performed, and funds are raised on a per capita basis.', "['Tianshang shengmu']"]
# ['04-04', '04-04', 'V075-2', '4/4: The celebration of Tiangong yuanshuai 田公元帅 is organized by the Chen 陈 Opera is performed.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['07-16', '07-16', 'V075-3', '7/16: the celebration of Sanyi jiaozhu 三一教主 is organized by the village as a whole. Opera is performed, and funds are raised on a per capita basis.', "['Sanyi jiaozhu']"]
# ['10-07', '10-07', 'V075-4', '10/7: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of Jiyi xingshê 积义兴社is organized by the Zhou 周. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-11', '10-11', 'V075-5', '10/11: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Jiqing zushê 积庆祖社is organized by the Chen 陈. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-14', '10-14', 'V076-1', '10/14: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Daoist ritual masters are invited to hold a jiao ritual 做醮.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-09', '04-09', 'V077-1', '4/9: The celebration of Tiangong yuanshuai 田公元帅 is organized by the village as a whole. Opera is performed and funds are raised on a per capita basis.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['07-09', '07-09', 'V077-2', '7/9: The celebration of Dage 大哥. Marionette plays are performed.', "['Dage']"]
# ['08-15', '08-15', 'V077-3', '8/15: The celebration of Liugong yuanshuai 刘公元帅 is organized by the village as a whole. Opera is performed and funds are raised on a per capita basis.', "['Liugong yuanshuai']"]
# ['10-02', '10-02', 'V077-4', '10/2: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Changyishê 长义社is organized by the Zheng 郑. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-03', '10-03', 'V077-5', '10/3: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Jiyishê 积义社is organized by the Hong 洪. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['10-04', '10-04', 'V077-6', '10/4: The celebration of the Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 of the Xianyishê 显义社is organized by the miscellaneous surnames 杂姓. Opera is performed.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-05', '03-05', 'V078-1', '3/5: The birthday celebration of Xuantian shangdi 玄天上帝.', "['Xuantian shangdi']"]
# ['05-18', '05-18', 'V078-2', '5/18: The birthday celebration of Lingguan dadi 灵官大帝. Marionette plays are performed.', "['Lingguan dadi']"]
# ['08-23', '08-23', 'V078-3', '8/23: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. On these occasions, opera or marionette plays are performed, and Daoist ritual masters may be invited to conduct rituals. These events are organized by the village as a whole, and funds are collected on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['02-03', '02-03', 'V079-1', '2/3: The celebration of Huoguang dadi 火官大帝 is held as part of the final evening festivities of Yuanxiao 尾晚元宵. Two days of opera are performed.', '[]']
# ...
# ['03-03', '03-03', 'V705-2', '3/3: The birthday celebration of Xuantian shangdi 玄天上帝.', "['Xuantian shangdi']"]
# ['05-05', '05-05', 'V705-3', '5/5: The birthday celebration of Wulu jiangjun 五路将军 and Wuxian lingguan 五显灵官.', "['Wulu jiangjun', 'Wuxian lingguan']"]
# ['06-06', '06-06', 'V705-4', '6/6: The birthday celebration of Fude zhengshen 福德正神. In celebration of the god, opera is performed for two to three days, and the entire village organizes the event together. Funds are gathered on a per capita basis.', "['Fude zhengshen']"]
# ['03-03', '03-03', 'V706-1', '3/3: Xuantian shangdi 玄天上帝 and Zunzhu mingwang 尊主明王 are celebrated by the village all together.', "['Xuantian shangdi', 'Zunzhu mingwang']"]
# ['04-18', '04-18', 'V706-2', 'The rest of the god’s birthdays are organized by each lineage branch: 4/18: The birthday celebration of Liugong yuanshuai 刘公元帅 is organized by the Jiucuo 旧厝 branch.', "['Liugong yuanshuai']"]
# ['05-05', '05-05', 'V706-3', '5/5: The birthday celebration of Jialuo dasheng 迦罗大圣 and Jin dajiangjun 金大将军 is organized by the Yaodou 窑兜 branch.', "['Jialuo dasheng']"]
# ['07-23', '07-23', 'V706-4', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君 and Fuma shengwang 福马圣王 is organized by the Weicuo 尾厝 branch; 9/9: The birthday celebration of Dutian yuanshuai 都天元帅 is organized by the Tianxia 田下 branch.', "['Dutian yuanshuai', 'Zhanggong shengjun']"]
# ['02-25', '02-25', 'V707-1', '2/25: The celebration of Qitian dasheng 齐天大圣 is organized by the Fang 方.', "['Qitian dasheng']"]
# ['03-03', '03-03', 'V707-2', '3/3: The celebration of Xuantian shangdi 玄天上帝, Lingguan dadi 灵官大 帝, Xuantan yuanshuai 玄坛元帅, Taiyi xiangu 太乙仙姑, and Zunzhu mingwang 尊主明王 is organized by the entire village all together.', "['Lingguan dadi', 'Taiyi xiangu', 'Xuantan yuanshuai', 'Xuantian shangdi', 'Zunzhu mingwang']"]
# ['04-18', '04-18', 'V707-3', '4/18: The celebration of Liugong yuanshuai 刘公元帅 is organized by the Xu 许.', "['Liugong yuanshuai']"]
# ['05-05', '05-05', 'V707-4', '5/5: The celebration of Jialuo dasheng 迦罗大圣 is are organized by the Xu 许.', "['Jialuo dasheng']"]
# ['07-23', '07-23', 'V707-5', '7/23: The celebration of Zhanggong shengjun 张公圣君 is organized by the Xu 许.', "['Zhanggong shengjun']"]
# ['08-23', '08-23', 'V707-6', '8/23: The celebration of Tiangong yuanshuai 田公元帅 is organized by the Fang 方.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['09-09', '09-09', 'V707-7', '9/9: The celebration of Dutian yuanshuai 都天元帅 is organized by the Li 李.', "['Dutian yuanshuai']"]
# ['02-10', '02-10', 'V708-1', '2/10: The birthday celebration of Falu dutong 法籙都统 is organized by the Chen of the third neighborhood 陈三甲.', "['Falu dutong']"]
# ['03-28', '03-28', 'V708-2', '3/28: The celebration for Zhusheng dadi 注生大帝 is organized by the entire village.', "['Zhusheng dadi']"]
# ['05-13', '05-13', 'V708-3', '5/13: The birthday celebration of Sima shengwang 司马圣王 is organized by the Chen of the first neighborhood 陈一甲.', "['Sima shengwang']"]
# ['06-01', '06-01', 'V708-4', '6/1: The birthday celebration of Zhongtian dasheng 中天大圣 is organized by the Chen of the second neighborhood 陈二甲.', "['Zhongtian dasheng']"]
# ['06-19', '06-19', 'V708-5', '6/19: The birthday celebration of Sandian zhenjun 三殿真君 and Qiugong shenghou 邱公圣侯 are organized by the Zheng 郑, Yu 俞, Cai 蔡, and Liu 刘 of the fourth neighborhood.', "['Qiugong shenghou', 'Sandian zhenjun']"]
# ['07-07', '07-07', 'V708-6', '7/7: The celebration of Wuan shengwang 武按圣王 is organized by the Chen of the second neighborhood 陈二甲.', "['Wuan shengwang']"]
# ['08-01', '08-01', 'V708-7', '8/1: The celebration of Fazhu xianfei 法主仙妃 is organized by the entire village.', "['Fazhu xianfei']"]
# ['02-10', '02-10', 'V709-1', '2/10: The birthday celebration of Falu dutong 法籙都统.', "['Falu dutong']"]
# ['03-16', '03-16', 'V709-2', '3/16: The birthday celebration of Xuantan yuanshuai 玄坛元帅.', "['Xuantan yuanshuai']"]
# ['05-13', '05-13', 'V709-3', '5/13: The birthday celebration of Sima shengwang 司马圣王.', "['Sima shengwang']"]
# ['06-02', '06-02', 'V709-4', '6/2: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['06-06', '06-06', 'V709-5', '6/6: The birthday celebration of Fude zhengshen 福 德正神.', "['Fude zhengshen']"]
# ['06-10', '06-10', 'V709-6', '6/10: The birthday celebration of Sandian zhenjun 三殿真君.', "['Sandian zhenjun']"]
# ['07-07', '07-07', 'V709-7', '7/7: The birthday celebration of Wuan shengwang 武按圣王.', "['Wuan shengwang']"]
# ['08-01', '08-01', 'V709-8', '8/1: The birthday celebration of Fazhu xianfei 法主仙妃.', "['Fazhu xianfei']"]
# ['08-22', '08-22', 'V709-9', '8/22: The birthday celebration of Guangze zunwang 广泽尊王. On each god’s birthday, opera is performed for two days. The celebrations are organized by the village all together, and funds are gathered according to shêfen (one’s share in the she) “灶分”, that is, by households.', "['Guangze zunwang']"]
# ['02-23', '02-23', 'V710-1', '2/23: the birthday of Qitian dasheng 齐天大圣 is celebrated.', "['Qitian dasheng']"]
# ['05-13', '05-13', 'V710-2', '5/13: the birthday of Sima shengwang 司马圣王 is celebrated. These events are organized by the village as a whole.', "['Sima shengwang']"]
# ['02-25', '02-25', 'V711-1', '2/25: The birthday celebration of Qitian dasheng 齐天大圣 is organized by the Chen 陈.', "['Qitian dasheng']"]
# ['03-03', '03-03', 'V711-2', '3/3: The birthday celebration of Xuantian shangdi 玄天上帝 is organized by the entire village.', "['Xuantian shangdi']"]
# ['04-09', '04-09', 'V711-3', '4/9: The birthday celebration of Tiangong yuanshuai 田公元帅 is organized by the Zheng 郑.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['04-18', '04-18', 'V711-4', '4/18: The birthday celebration of Liugong yuanshuai 刘公元帅 is organized by the Lin 林 5/5: The birthday celebration of Jialuo dasheng 伽罗大圣 is organized by the Zheng 郑.', "['Jialuo dasheng', 'Liugong yuanshuai']"]
# ['07-23', '07-23', 'V711-5', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君 is organized by the Zheng 郑.', "['Zhanggong shengjun']"]
# ['08-03', '08-03', 'V711-6', '8/3: The birthday celebration of Zunzhu mingwang 尊主明王 is organized by the entire village.', "['Zunzhu mingwang']"]
# ['02-25', '02-25', 'V712-1', '2/25: The celebration of Qitian dasheng 齐天大圣 is organized by the Fang 方.', "['Qitian dasheng']"]
# ['03-03', '03-03', 'V712-2', '3/3: The celebration of Xuantian shangdi 玄天上帝 is organized by the village as a whole.', "['Xuantian shangdi']"]
# ['03-28', '03-28', 'V712-3', '3/28: The celebration of Dongyue dadi 东岳大帝 is organized by the village as a whole.', "['Dongyue dadi']"]
# ['04-07', '04-07', 'V712-4', '4/7: The celebration of Tiangong yuanshuai 田公元帅 is organized by the Fang 方.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['04-18', '04-18', 'V712-5', '4/18: The celebration of Liugong yuanshuai 刘公元帅 is organized by the Xu 许.', "['Liugong yuanshuai']"]
# ['05-05', '05-05', 'V712-6', '5/5: The celebration of Jialuo dasheng 伽罗大圣 is organized by the Fang 方.', "['Jialuo dasheng']"]
# ['06-01', '06-01', 'V712-7', '6/1: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后 土夫人 is organized by the village as a whole.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V712-8', '7/23: The celebration of Zhanggong shengjun 张公圣君 is organized by the Cai 蔡.', "['Zhanggong shengjun']"]
# ['09-09', '09-09', 'V712-9', '9/9: The celebration of Dutian yuanshuai 都天元帅 is organized by the Fang 方.', "['Dutian yuanshuai']"]
# ['02-02', '02-02', 'V713-1', '2/2: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['02-25', '02-25', 'V713-2', '2/25: The birthday celebration of Qitian dasheng 齐天大圣诞.', "['Qitian dasheng']"]
# ['03-03', '03-03', 'V713-3', '3/3: The birthday celebration of Xuantian shangdi 玄天上帝.', "['Xuantian shangdi']"]
# ['04-07', '04-07', 'V713-4', '4/7: The birthday celebration of Tiangong yuanshuai 田公元帅.', "['Tiangong', 'Tiangong yuanshuai']"]
# ['05-01', '05-01', 'V713-5', '5/1: The birthday celebration of Xiaogong yuanshuai 肖公元帅.', '[]']
# ['07-07', '07-07', 'V713-6', '7/7: The birthday celebration of Shangjie Zhu daniangniang 上界朱大娘.', '[]']
# ['07-23', '07-23', 'V713-7', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君.', "['Zhanggong shengjun']"]
# ['12-10', '12-10', 'V713-8', '12/10: The birthday celebration of Baosong furen 抱送夫人. On each of these god’s birthdays opera is performed for two days. These events are organized by the village as a whole. Funds are gathered on a per capita basis.', "['Baosong furen']"]
# ['06-06', '06-06', 'V714-1', '6/6: The birthday of Zunzhu mingwang 尊主明王 and Houtu furen 后土 夫人 is celebrated.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V714-2', '7/23: The birthday of Zhanggong shengjun 张公圣君 is celebrated.', "['Zhanggong shengjun']"]
# ['09-09', '09-09', 'V714-3', '9/9: The birthday of Dutian yuanshuai 都天元帅 is celebrated. On each of these occasions, opera is performed for two to three days. The events are organized by the village as a whole and funds are raised on a per capita basis.', "['Dutian yuanshuai']"]
# ['01-09', '01-09', 'V715-1', '1/9: The celebration of Yuhuang dadi 玉皇大帝, Zunzhu mingwang 尊 主明王 and Houtu furen 后土夫人 is organized by the village as a whole.', "['Houtu furen', 'Yuhuang dadi', 'Zunzhu mingwang']"]
# ['02-25', '02-25', 'V715-2', '2/25: The celebration of Qitian dasheng 齐天大圣 is organized by the Huang 黄.', "['Qitian dasheng']"]
# ['03-03', '03-03', 'V715-3', '3/3: The celebration of Xuantian shangdi 玄天上帝 is organized by the village as a whole.', "['Xuantian shangdi']"]
# ['05-05', '05-05', 'V715-4', '5/5: The celebrating of Jialuo dasheng 伽罗大圣 is organized by the Dai 戴.', "['Jialuo dasheng']"]
# ['06-15', '06-15', 'V715-5', '6/15: The celebration of Beishan dawang 北山大王 is organized by the village as a whole.', "['Beishan dawang']"]
# ['07-23', '07-23', 'V715-6', '7/23: The celebration of Zhanggong shengjun 张公圣君 is organized by the Li 李 7/10: The celebration of Jiushiye 九使爷 ( Jiucha dashen 纠察大神) is organized by the Fu 傅.', "['Zhanggong shengjun']"]
# ['09-28', '09-28', 'V715-7', '9/28: The celebration of Zhonglie shenghou 忠烈圣侯 is organized by the Liu 刘. On each of these celebrations, opera is performed for two days.', '[]']
# ['01-09', '01-09', 'V716-1', '1/9: The birthday celebration of Yuhuang dadi 玉皇大帝, Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Yuhuang dadi', 'Zunzhu mingwang']"]
# ['02-02', '02-02', 'V716-2', '2/2: The birthday celebration of Guangze zunwang 广泽尊王.', "['Guangze zunwang']"]
# ['03-03', '03-03', 'V716-3', '3/3: The birthday celebration of Xuantian shangdi 玄天上帝.', "['Xuantian shangdi']"]
# ['05-04', '05-04', 'V716-4', '5/4: The birthday celebration of Haotian yuanshuai 昊天元帅.', '[]']
# ['06-06', '06-06', 'V716-5', '6/6: The birthday celebration of Fude zhengshen 福德正神.', "['Fude zhengshen']"]
# ['08-14', '08-14', 'V716-6', '8/14: The birthday celebration of Guishan dawang 龟山大王. For each of these celebrations, opera is performed for two days, and the event is organized by the village as a whole.', '[]']
# ['02-02', '02-02', 'V717-1', 'The following gods are celebrated on the dates indicated: 2/2: Qitian dasheng. 齐天大圣.', "['Qitian dasheng']"]
# ['10-27', '10-27', 'V717-2', '10/27: Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. For each of these celebrations, opera is performed for two days, and the event is organized by the village as a whole.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-13', '04-13', 'V718-1', '4/13: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V718-2', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君.', "['Zhanggong shengjun']"]
# ['08-28', '08-28', 'V718-3', '8/28: The birthday celebration of Anling shenggong 安灵圣公.', "['Anling shenggong']"]
# ['09-09', '09-09', 'V718-4', '9/9: The birthday celebration of Jiushi 九使.', '[]']
# ['09-10', '09-10', 'V718-5', '9/10: The birthday celebration of Shishi 十使.', '[]']
# ['09-11', '09-11', 'V718-6', '9/11: The birthday celebration of Shiyishi 十一使. For each of these celebrations, opera is performed for two or three days, and the event is organized by the village as a whole. Funds are raised on a per capita basis.', '[]']
# ['02-25', '02-25', 'V719-1', '2/25: The birthday celebration of Qitian dasheng 齐天大圣.', "['Qitian dasheng']"]
# ['07-23', '07-23', 'V719-2', '7/23: The birthday celebration of Zhanggong shengjun 张公圣君.', "['Zhanggong shengjun']"]
# ['08-21', '08-21', 'V719-3', '8/21: The birthday celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人. Each of these occasions is marked with two days of opera.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-03', '03-03', 'V719-4', 'On the following occasions, only offerings are laid out: 3/3: The birthday of Xuantian shangdi 玄天上帝.', "['Xuantian shangdi']"]
# ['02-02', '02-02', 'V719-5', '2/2: The birthday of Guangze zunwang 广泽尊王.', "['Guangze zunwang']"]
# ['04-07', '04-07', 'V719-6', '4/7 and 8/25: The feast days of Zhonglie (Tiangong 田公) yuanshuai 忠烈 元帅.', "['Tiangong']"]
# ['04-18', '04-18', 'V719-7', '4/18: The feast days for Fumo (Liugong 刘公) yuanshuai 伏魔元帅.', '[]']
# ['07-07', '07-07', 'V719-8', '7/7: The feast days for the Lubu dashen 鲁部大神 and Tianqian shengmu 天前圣母. All these occasions are organized by the village as a whole, and funds are raised on a per capita basis.', "['Lubu dashen', 'Tianqian shengmu']"]
# ['06-06', '06-06', 'V720-1', '6/6: The birthday celebration of Fude zhengshen 福德正神.', "['Fude zhengshen']"]
# ['07-07', '07-07', 'V720-2', '7/7: The birthday celebration of Lubu dashen 鲁部大神 and Chen Jinggu 陈靖姑.', "['Chen Jinggu', 'Lubu dashen']"]
# ['08-18', '08-18', 'V720-3', '8/18: The birthday celebration of Tiegong taishi 铁公太师. For each of these celebrations, opera is performed for two or three days, and the event is organized by the village as a whole. Funds are raised on a per capita basis.', "['Tiegong taishi']"]
# ['03-03', '03-03', 'V721-1', '3/3: The birthday of Xuantian shangdi 玄天上帝 is celebrated.', "['Xuantian shangdi']"]
# ['03-23', '03-23', 'V721-2', '3/23: The birthday of Tianshang shengmu 天上圣母 is celebrated.', "['Tianshang shengmu']"]
# ['03-29', '03-29', 'V721-3', '3/29: The birthday of Liu shenghou 柳圣侯 and Jin shenghou 金圣侯 are celebrated.', '[]']
# ['06-10', '06-10', 'V721-4', '6/10: The birthday of Zunzhu mingwang 尊主明王 and Houtu furen 后土 夫人 are celebrated. For each of these celebrations, opera is performed for two or three days, and the event is organized by the village as a whole. Funds are raised on a per capita basis.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['03-15', '03-15', 'V722-1', '3/15: The celebration of Ciji zhenjun 慈济真君 is held and opera is performed for two days.', "['Ciji zhenjun']"]
# ['03-23', '03-23', 'V722-2', '3/23: The celebration of Tianshang shengmu 天上圣母 is held and opera is performed for two days.', "['Tianshang shengmu']"]
# ['07-23', '07-23', 'V722-3', '7/23: The celebration of Zhanggong shengjun 张公圣君 is organized by the Huiqingtang 会庆堂. Opera is performed for five days and each year with an intercalary seventh month there is a procession through the entire thirteen village alliance.', "['Zhanggong shengjun']"]
# ['06-12', '06-12', 'V723-1', '6/12: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held and opera is performed for two days.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['07-23', '07-23', 'V723-2', '7/23: The celebration of Zhanggong shengjun 张公圣君 is held and opera is performed for two days.', "['Zhanggong shengjun']"]
# ['03-13', '03-13', 'V724-1', '3/13: The celebration of Zunzhu mingwang 尊主明王 and Houtu furen 后土夫人 is held and opera is performed for two days.', "['Houtu furen', 'Zunzhu mingwang']"]
# ['04-15', '04-15', 'V724-2', '4/15: The celebration of Wangtaizi 王太子 is held and opera is performed for two days.', '[]']
# ['06-06', '06-06', 'V724-3', '6/6: The celebration of Fude zhengshen 福德正神 is held and opera is performed for two days.', "['Fude zhengshen']"]
# ['10-12', '10-12', 'V724-4', '10/12: The celebration of Heihu dashen 黑虎大神 is held and opera is performed for two days.', "['Heihu dashen']"]

# %%
# DO NOT USE
# Process text for the alliance search function

import json, csv, re

output = []

with open("./output/Alliance_raw_text.json") as infile:
    indata = json.load(infile)
    
    for element in indata:
        outputext = element["UID_A"] + ": " + element["name"] + " " + element["name_zh"]
        
        output.append({
            "id": element["UID_A"],
            "text": outputext
        })
        
with open("./output/Alliance_search.json", "w") as outfile:
    json.dump(output, outfile, ensure_ascii=False)

    outfile.close()

# %%
# DO NOT USE
# Process text for the calendar function

import json, csv, re

output = []
    
with open("./output/birthday_celebrations.json") as infile:
    indata = json.load(infile)
    
    output=[]

    # Create array
    for i in range(1,13):
        month = str(i)
        if len(month) == 1:
            month="0"+month
        
        for i in range(1,32):
            day = str(i)
            if len(day) == 1:
                day="0"+day
            date = month + "-" + day

            output.append({
                "date": date,
                "ID": [],
                "weight": 0
            })
    
    for entry in indata:
        
           # one-day event?
        if entry["startdate"] == entry["enddate"]:
            
            ## Filter out entries without dates
            if entry["startdate"] == "MM-DD":
                continue;
            else:
                correct_entry = list(filter(lambda k: k["date"] == entry["startdate"], output))[0]
                
            correct_entry["weight"] = correct_entry["weight"] + 1
            correct_entry["ID"].append(entry["uid_r"])
            
        else:
            start_date = re.split("-", entry["startdate"])
            m1 = int(start_date[0])
            d1 = int(start_date[1])
            
            end_date = re.split("-", entry["enddate"])
            m2 = int(end_date[0])
            d2 = int(end_date[1])
            
            duration = 31 * (m2-m1) - d1 + d2 + 1
            
            if m1 == m2:
                if (len(str(m1))) == 1:
                    m1 = "0" + str(m1)
                
                for i in range (d1, d2+1):
                    d = str(i)
                    if (len(str(i))) == 1:
                        d = "0" + str(i)
                    
                    correct_entry = list(filter(lambda k: k["date"] == str(m1)+"-"+d, output))[0]
                    
                    correct_entry["weight"] = correct_entry["weight"] + (1/duration)
                    
                    correct_entry["ID"].append(entry["uid_r"])
        
        
with open("./output/birthdays_cal.json", "w") as outfile:
    json.dump(output, outfile, ensure_ascii=False)

    outfile.close()

# %%
# Loading surname data
import json, csv, re

output = []
    
with open("./output/birthdays_cal.json") as infile:
    indata = json.load(infile)
# Out:
# [{'month': '1', 'date': '01-01', 'ID': ['V542-1', 'V543-1'], 'weight': 0.6666666666666666}, {'month': '1', 'date': '01-02', 'ID': ['V542-1', 'V543-1'], 'weight': 0.6666666666666666}, {'month': '1', 'date': '01-03', 'ID': ['V542-1', 'V543-1', 'V558-1'], 'weight': 1.6666666666666665}, {'month': '1', 'date': '01-04', 'ID': ['V311-1', 'V679-9'], 'weight': 1.5}, {'month': '1', 'date': '01-05', 'ID': ['V179-1', 'V311-1', 'V391-1', 'V577-1', 'V690-1'], 'weight': 4.5}, {'month': '1', 'date': '01-06', 'ID': ['V632-1', 'V636-1', 'V637-1', 'V638-1', 'V639-1', 'V640-1', 'V641-1', 'V691-1'], 'weight': 8}, {'month': '1', 'date': '01-07', 'ID': ['V139-1', 'V415-1', 'V576-1', 'V584-1'], 'weight': 3.0}, {'month': '1', 'date': '01-08', 'ID': ['V477-1', 'V486-1', 'V576-1', 'V584-1'], 'weight': 3.0}, {'month': '1', 'date': '01-09', 'ID': ['V004-1', 'V132-1', 'V134-1', 'V144-1', 'V163-1', 'V171-1', 'V317-1', 'V338-1', 'V422-1', 'V470-1', 'V551-1', 'V598-1', 'V606-1', 'V621-1', 'V629-1', 'V632-2', 'V650-1', 'V653-1', 'V660-1', 'V672-1', 'V679-10', 'V698-1', 'V705-1', 'V715-1', 'V716-1'], 'weight': 25}, {'month': '1', 'date': '01-10', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-11', 'ID': ['V594-5'], 'weight': 1}, {'month': '1', 'date': '01-12', 'ID': ['V423-1', 'V575-7'], 'weight': 2}, {'month': '1', 'date': '01-13', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-14', 'ID': ['V063-1', 'V109-1', 'V129-1', 'V132-2', 'V133-1', 'V139-2', 'V144-2', 'V176-1', 'V355-1', 'V399-1', 'V415-2', 'V443-1', 'V575-1', 'V601-1'], 'weight': 14}, {'month': '1', 'date': '01-15', 'ID': ['V128-1', 'V225-1', 'V235-1', 'V443-2', 'V566-1', 'V576-2'], 'weight': 5.5}, {'month': '1', 'date': '01-16', 'ID': ['V576-2', 'V577-2', 'V619-1', 'V620-1', 'V629-2', 'V634-1', 'V646-1'], 'weight': 6.5}, {'month': '1', 'date': '01-17', 'ID': ['V138-1', 'V301-1'], 'weight': 2}, {'month': '1', 'date': '01-18', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-19', 'ID': ['V246-1', 'V301-2', 'V350-1', 'V423-2'], 'weight': 4}, {'month': '1', 'date': '01-20', 'ID': ['V279-1', 'V491-1'], 'weight': 2}, {'month': '1', 'date': '01-21', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-22', 'ID': ['V354-1', 'V376-1', 'V673-1'], 'weight': 3}, {'month': '1', 'date': '01-23', 'ID': ['V695-1'], 'weight': 1}, {'month': '1', 'date': '01-24', 'ID': ['V455-1'], 'weight': 1}, {'month': '1', 'date': '01-25', 'ID': ['V100-1', 'V130-1', 'V487-1'], 'weight': 2.5}, {'month': '1', 'date': '01-26', 'ID': ['V487-1', 'V496-1'], 'weight': 1.5}, {'month': '1', 'date': '01-27', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-28', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-29', 'ID': ['V170-9', 'V309-1', 'V341-1'], 'weight': 3}, {'month': '1', 'date': '01-30', 'ID': [], 'weight': 0}, {'month': '1', 'date': '01-31', 'ID': [], 'weight': 0}, {'month': '2', 'date': '02-01', 'ID': ['V079-3', 'V139-3', 'V217-1', 'V304-1', 'V487-2', 'V633-1', 'V652-1'], 'weight': 6.032258064516129}, {'month': '2', 'date': '02-02', 'ID': ['V079-3', 'V131-1', 'V172-1', 'V185-1', 'V186-1', 'V187-1', 'V222-1', 'V473-1', 'V549-1', 'V557-1', 'V563-1', 'V581-1', 'V586-1', 'V587-1', 'V588-1', 'V589-1', 'V590-1', 'V628-1', 'V687-1', 'V696-1', 'V696-2', 'V697-1', 'V699-1', 'V700-1', 'V713-1', 'V716-2', 'V717-1', 'V719-5'], 'weight': 27.032258064516128}, {'month': '2', 'date': '02-03', 'ID': ['V079-1', 'V079-3', 'V232-1', 'V235-2', 'V370-1', 'V378-1', 'V391-2', 'V415-3', 'V583-1'], 'weight': 8.032258064516128}, {'month': '2', 'date': '02-04', 'ID': ['V079-3', 'V480-1'], 'weight': 1.032258064516129}, {'month': '2', 'date': '02-05', 'ID': ['V079-3', 'V301-3', 'V435-1', 'V629-3', 'V632-3', 'V634-2'], 'weight': 5.032258064516129}, {'month': '2', 'date': '02-06', 'ID': ['V079-3', 'V474-1'], 'weight': 1.032258064516129}, {'month': '2', 'date': '02-07', 'ID': ['V079-3'], 'weight': 0.03225806451612903}, {'month': '2', 'date': '02-08', 'ID': ['V079-3', 'V152-1', 'V155-1', 'V156-1', 'V215-1', 'V355-2', 'V694-1'], 'weight': 6.03225806451612 ...
