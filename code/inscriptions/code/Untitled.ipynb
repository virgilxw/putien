# %%
import os, re, json

# Scanner to break text into alliance chunks

with open('Alliance_raw_text.json') as alliance_file:
    alliance_index = json.load(alliance_file)
    
    # priming searching indexes
    alliance_no = 0
    number = alliance_index[0]["UID_A"][1:4]
    buffer=[]
    alliance_bloc=[]

    with open('South.txt', mode='r', encoding='utf-8') as infile:

        # while alliance_no < alliance_index:
        
            for line in infile:
                if line[0:3] == number and len(line.split()) == 2:
                    # Found correct starting line for each alliance
                    alliance_bloc.append({
                        "UID": alliance_index[alliance_no-1]["UID_A"],
                        "text": buffer
                    })
                    buffer=[]
                    buffer.append(line)

                    if alliance_no+1 < len(alliance_index):
                        alliance_no = alliance_no + 1
                    
                    number = alliance_index[alliance_no]["UID_A"][1:4]

                    print(number)
                    
                else:
                    buffer.append(line)
                
del alliance_bloc[0]

print(alliance_no, " alliances found!")

with open('nanyang_aliiance_textblock.json', 'w', encoding='utf-8') as fp:
    json.dump(alliance_bloc, fp, ensure_ascii=False)
# Out:
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# 058
# 059
# 060
# 061
# 062
# 063
# 064
# 065
# 066
# 067
# 068
# 069
# 070
# 071
# 072
# 073
# 074
# 075
# 076
# 077
# 078
# 079
# 080
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 088
# 089
# 090
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 153
# 152  alliances found!

# %%
import os, re, json

with open('village_index.json') as village_file:
    village_index = json.load(village_file)
    alliance_counter=0
    
    with open('nanyang_aliiance_textblock.json') as result_file:
        text_block = json.load(result_file)
        buffer=[]
        out=[]
        
        for entry in text_block:            
            village_counter = 0
            print("parsing", entry["UID"])
            
            for line in entry["text"]:
    
                # check for match
                if len(line) > 0:
    
                    if line.strip() == village_index[alliance_counter]["Villages"][village_counter]["Name_zh"] :
        
        
                        print("Found start of entry for", village_index[alliance_counter]["Villages"][village_counter]["UID_V"],  village_index[alliance_counter]["Villages"][village_counter]["Name_zh"])
                    
                        if village_counter == 0 :
                            out.append({
                                "UID": entry["UID"],
                                "text": buffer
                            })
                        else:
                            out.append({
                                "UID": village_index[alliance_counter]["Villages"][village_counter-1]["UID_V"],
                                "text": buffer
                            })
                        buffer=[]
                
                        if village_counter+1 < len(village_index[alliance_counter]["Villages"]):
                            village_counter = village_counter + 1 
                            
                            
                buffer.append(line)
            
            out.append({"UID": village_index[alliance_counter]["Villages"][village_counter]["UID_V"],
                                "text": buffer})
            buffer=[]
            
            print("Completed parsing", entry["UID"], ".", village_counter, "of", len(village_index[alliance_counter]["Villages"]), "villages found")
                
            alliance_counter = alliance_counter + 1
        
with open('results2.json', 'w', encoding='utf-8') as fp:
    json.dump(out, fp, ensure_ascii=False)
# Out:
# parsing A001
# Found start of entry for V001 陂头
# Found start of entry for V002 吴门
# Found start of entry for V003 铁灶
# Found start of entry for V004 白玉岭
# Completed parsing A001 . 3 of 4 villages found
# parsing A002
# Found start of entry for V005 龙前
# Found start of entry for V006 莆仔
# Found start of entry for V007 上横山
# Found start of entry for V008 下横山
# Completed parsing A002 . 3 of 4 villages found
# parsing A003
# Found start of entry for V009 青垞
# Found start of entry for V010 云庄
# Found start of entry for V011 沟口
# Found start of entry for V012 沟东
# Found start of entry for V013 沟西
# Found start of entry for V014 前墩
# Found start of entry for V015 中墩
# Found start of entry for V016 后墩
# Completed parsing A003 . 7 of 8 villages found
# parsing A004
# Found start of entry for V017 后面
# Found start of entry for V018 顶厝
# Found start of entry for V019 下厝
# Found start of entry for V020 沟下
# Found start of entry for V021 西尾
# Found start of entry for V022 苍头
# Found start of entry for V023 隔头
# Completed parsing A004 . 6 of 7 villages found
# parsing A005
# Found start of entry for V024 南梧塘
# Found start of entry for V025 下渠头
# Found start of entry for V026 东亭
# Found start of entry for V027 塘东
# Found start of entry for V028 后廖
# Completed parsing A005 . 4 of 5 villages found
# parsing A006
# Found start of entry for V029 下墩
# Found start of entry for V030 渠桥
# Found start of entry for V031 东岭
# Found start of entry for V032 塘边
# Found start of entry for V033 度边
# Found start of entry for V034 巷口
# Found start of entry for V035 后亭
# Found start of entry for V036 圳尾
# Completed parsing A006 . 7 of 8 villages found
# parsing A007
# Found start of entry for V037 洋尾
# Found start of entry for V038 溪东
# Found start of entry for V039 东坝
# Completed parsing A007 . 2 of 3 villages found
# parsing A008
# Found start of entry for V040 溪泉头
# Found start of entry for V041 三社
# Found start of entry for V042 埭里
# Completed parsing A008 . 2 of 3 villages found
# parsing A009
# Found start of entry for V043 步云
# Completed parsing A009 . 0 of 1 villages found
# parsing A010
# Found start of entry for V044 白埕
# Found start of entry for V045 前面
# Found start of entry for V046 屈边
# Found start of entry for V047 后社
# Found start of entry for V048 后埭
# Found start of entry for V049 园顶
# Found start of entry for V050 浦尾
# Completed parsing A010 . 6 of 7 villages found
# parsing A011
# Found start of entry for V051 后周
# Found start of entry for V052 后彭
# Found start of entry for V053 后湖
# Found start of entry for V054 前湖
# Found start of entry for V055 灰壁
# Found start of entry for V056 西厝
# Found start of entry for V057 北厝
# Found start of entry for V058 尾厝
# Completed parsing A011 . 7 of 8 villages found
# parsing A012
# Found start of entry for V059 后亭
# Found start of entry for V060 度边
# Found start of entry for V061 东店
# Found start of entry for V062 三角曾
# Completed parsing A012 . 3 of 4 villages found
# parsing A013
# Found start of entry for V063 厝柄
# Completed parsing A013 . 0 of 1 villages found
# parsing A014
# Found start of entry for V064 沟岑
# Found start of entry for V065 后郑
# Found start of entry for V066 后戴
# Found start of entry for V067 溝東
# Found start of entry for V068 上墩
# Found start of entry for V069 腰沟
# Found start of entry for V070 沛尾
# Found start of entry for V071 西角
# Completed parsing A014 . 7 of 8 villages found
# parsing A015
# Found start of entry for V072 中境
# Found start of entry for V073 下何
# Found start of entry for V074 黄厝里
# Found start of entry for V075 后巷
# Found start of entry for V076 大路
# Found start of entry for V077 山坪
# Found start of entry for V078 紅山
# Completed parsing A015 . 6 of 7 villages found
# parsing A016
# Found start of entry for V079 善乡
# Completed parsing A016 . 0 of 1 villages found
# parsing A017
# Found start of entry for V080 頂厝
# Found start of entry for V081 顶宋
# Found start of entry for V082 下宋
# Found start of entry for V083 西利
# Found start of entry for V084 下亭
# Found start of entry for V085 后利
# Completed parsing A017 . 5 of 6 villages found
# parsing A018
# Found start of entry for V086 樟桥
# Completed parsing A018 . 0 of 1 villages found
# parsing A019
# Found start of entry for V087 洋埕
# Completed parsing A019 . 0 of 1 villages found
# parsing A020
# Found start of entry for V088 钱塘
# Found start of entry for V089 岭顶
# Found start of entry for V090 后许
# Found start of entry for V091 后院
# Found start of entry for V092 黄园
# Found start of entry for V093 下庄
# Found start of entry for V094 上坑
# Completed parsing A020 . 6 of 7 villages found
# parsing A021
# Found start of entry for V095 塘頭
# Found start of entry for V096 东洙
# Found start of entry for V097 芦坑
# Found start of entry for V098 山兜
# Completed parsing A021 . 3 of 4 villages found
# parsing A022
# Found start of entry for V099 瑶台
# Completed parsing A022 . 0 of 1 villages found
# parsing A023
# Found start of entry for V100 定庄
# Found start of entry for V101 长川
# Found start of entry for V102 下阪
# Found start of entry for V103 田厝
# Found start of entry for V104 上院前
# Found start of entry for V105 下院前
# Completed parsing A023 . 5 of 6 villages found
# parsing A024
# Found start of entry for V106 桂岭
# Found start of entry for V107 亭下
# Found start of entry for V108 东井
# Found start of entry for V109 塘尾
# Found start of entry for V110 书院口
# Found start of entry for V111 市下
# Found start of entry for V112 双星井
# Found start of entry for V113 安兴
# Completed parsing A024 . 7 of 8 villages found
# parsing A025
# Found start of entry for V114 桥头
# Found start of entry for V115 西厝
# Found start of entry for V116 阪头
# Found start of entry for V117 社前
# Found start of entry for V118 树下
# Found start of entry for V119 田坝
# Found start of entry for V120 金墩
# Found start of entry for V121 龙度
# Completed parsing A025 . 7 of 8 villages found
# parsing A026
# Found start of entry for V122 吾埕
# Found start of entry for V123 埕尾
# Found start of entry for V124 坑柄
# Found start of entry for V125 珂里
# Found start of entry for V126 下湖
# Completed parsing A026 . 4 of 5 villages found
# parsing A027
# Found start of entry for V127 清中
# Found start of entry for V128 清后
# Found start of entry for V129 清前
# Completed parsing A027 . 2 of 3 villages found
# parsing A028
# Found start of entry for V130 西洪
# Completed parsing A028 . 0 of 1 villages found
# parsing A029
# Found start of entry for V131 桥兜
# Found start of entry for V132 下江头
# Found start of entry for V133 下埭
# Found start of entry for V134 西利
# Found start of entry for V135 余埭
# Completed parsing A029 . 4 of 5 villages found
# parsing A030
# Found start of entry for V136 林墩
# Found start of entry for V137 江西
# Found start of entry for V138 龙华
# Completed parsing A030 . 2 of 3 villages found
# parsing A031
# Found start of entry for V139 江东
# Completed parsing A031 . 0 of 1 villages found
# parsing A032
# Found start of entry for V140 海滨
# Completed parsing A032 . 0 of 1 villages found
# parsing A033
# Found start of entry for V141 遮浪
# Completed parsing A033 . 0 of 1 villages found
# parsing A034
# Found start of entry for V142 华堤
# Found start of entry for V143 华中
# Found start of entry for V144 华东
# Completed parsing A034 . 2 of 3 villages found
# parsing A035
# Found start of entry for V145 井埔
# Found start of entry for V146 后洙
# Found start of entry for V147 塔兜
# Completed parsing A035 . 2 of 3 villages found
# parsing A036
# Found start of entry for V148 长坑
# Found start of entry for V149 五龙
# Found start of entry for V150 沟边
# Found start of entry for V151 道美
# Completed parsing A036 . 3 of 4 villages found
# parsing A037
# Found start of entry for V152 梧巷
# Found start of entry for V153 东张
# Found start of entry for V154 西张
# Found start of entry for V155 朱厝
# Found start of entry for V156 西沟
# Found start of entry for V157 西园
# Found start of entry for V158 康厝
# Found start of entry for V159 吴厝
# Found start of entry for V160 山前仔
# Completed parsing A037 . 8 of 9 villages found
# parsing A038
# Found start of entry for V161 惠洋
# Completed parsing A038 . 0 of 1 villages found
# parsing A039
# Found start of entry for V162 东埭
# Completed parsing A039 . 0 of 1 villages found
# parsing A040
# Found start of entry for V163 金山
# Completed parsing A040 . 0 of 1 villages found
# parsing A041
# Found start of entry for V164 东甲
# Completed parsing A041 . 0 of 1 villages found
# parsing A042
# Found start of entry for V165 上鄒
# Found start of entry for V166 下鄒
# Found start of entry for V167 東厝
# Found start of entry for V168 鄭厝
# Completed parsing A042 . 3 of 4 villages found
# parsing A043
# Found start of entry for V169 斗南
# Completed parsing A043 . 0 of 1 villages found
# parsing A044
# Found start of entry for V170 屏山
# Completed parsing A044 . 0 of 1 villages found
# parsing A045
# Found start of entry for V171 东乡
# Found start of entry for V172 后积
# Found start of entry for V173 歧厝
# Found start of entry for V174 洋边
# Found start of entry for V175 前程口
# Found start of entry for V176 楼下
# Found start of entry for V177 后程口
# Completed parsing A045 . 6 of 7 villages found
# parsing A046
# Found start of entry for V178 埕边
# Found start of entry for V179 下陈
# Found start of entry for V180 沟戈
# Found start of entry for V181 码头
# Found start of entry for V182 坊井
# Found start of entry for V183 社厝
# Found start of entry for V184 北高
# Completed parsing A046 . 6 of 7 villages found
# parsing A047
# Found start of entry for V185 上坑园
# Found start of entry for V186 下坑园
# Found start of entry for V187 东渡
# Found start of entry for V188 岭头
# Found start of entry for V189 墓前
# Found start of entry for V190 上院后
# Found start of entry for V191 下院后
# Found start of entry for V192 前墩
# Completed parsing A047 . 7 of 8 villages found
# parsing A048
# Found start of entry for V193 郑塘
# Completed parsing A048 . 0 of 1 villages found
# parsing A049
# Found start of entry for V194 宋墓
# Found start of entry for V195 山头
# Found start of entry for V196 船渡
# Completed parsing A049 . 2 of 3 villages found
# parsing A050
# Found start of entry for V197 蓝田
# Found start of entry for V198 后湖
# Found start of entry for V199 官埔
# Found start of entry for V200 下郑
# Found start of entry for V201 上辛
# Found start of entry for V202 后巷
# Found start of entry for V203 下可塘
# Found start of entry for V204 上可塘
# Found start of entry for V205 顶溪
# Found start of entry for V206 濑宅
# Found start of entry for V207 草莽
# Found start of entry for V208 苏塘
# Found start of entry for V209 新徐
# Found start of entry for V210 旧徐
# Found start of entry for V211 墓柄
# Found start of entry for V212 石兜
# Completed parsing A050 . 15 of 16 villages found
# parsing A051
# Found start of entry for V213 陈厝
# Found start of entry for V214 吴厝
# Found start of entry for V215 后黄
# Found start of entry for V216 后井
# Found start of entry for V217 大邱
# Found start of entry for V218 福禄山
# Found start of entry for V219 林柄
# Found start of entry for V220 顶社
# Found start of entry for V221 北埔
# Completed parsing A051 . 8 of 9 villages found
# parsing A052
# Found start of entry for V222 上坝边
# Found start of entry for V223 下坝边
# Found start of entry for V224 田洋
# Found start of entry for V225 苍店
# Found start of entry for V226 下店
# Found start of entry for V227 林厝
# Found start of entry for V228 东津
# Found start of entry for V229 山頂
# Found start of entry for V230 坑尾
# Found start of entry for V231 东卓
# Found start of entry for V232 西卓
# Found start of entry for V233 黄林
# Found start of entry for V234 云塘
# Completed parsing A052 . 12 of 13 villages found
# parsing A053
# Found start of entry for V235 徐厝
# Found start of entry for V236 松亭
# Found start of entry for V237 后社
# Found start of entry for V238 林坑
# Found start of entry for V239 登鳌头
# Found start of entry for V240 院前
# Found start of entry for V241 前郑
# Found start of entry for V242 西津
# Found start of entry for V243 杨山
# Found start of entry for V244 赤岑
# Found start of entry for V245 西蔡
# Found start of entry for V246 岭下
# Found start of entry for V247 前林
# Found start of entry for V248 上林
# Found start of entry for V249 大埔
# Found start of entry for V250 下尾
# Found start of entry for V251 定固
# Found start of entry for V252 后洙
# Completed parsing A053 . 17 of 18 villages found
# parsing A054
# Found start of entry for V253 西山
# Found start of entry for V254 泌头
# Found start of entry for V255 山兜
# Completed parsing A054 . 2 of 3 villages found
# parsing A055
# Found start of entry for V256 东埔余
# Found start of entry for V257 蚁厝
# Found start of entry for V258 后董
# Found start of entry for V259 梅林
# Found start of entry for V260 陈山头
# Found start of entry for V261 下庄
# Found start of entry for V262 大埔
# Completed parsing A055 . 6 of 7 villages found
# parsing A056
# Found start of entry for V263 洋面
# Found start of entry for V264 东郭
# Found start of entry for V265 亥灶
# Found start of entry for V266 板厝
# Found start of entry for V267 侯厝
# Found start of entry for V268 桥头
# Found start of entry for V269 下西
# Completed parsing A056 . 6 of 7 villages found
# parsing A057
# Found start of entry for V270 林桂
# Found start of entry for V271 马竹杭
# Found start of entry for V272 彭墓
# Found start of entry for V273 赤松
# Found start of entry for V274 上林
# Found start of entry for V275 徐柯
# Found start of entry for V276 下余
# Completed parsing A057 . 6 of 7 villages found
# parsing A058
# Found start of entry for V277 新塘
# Found start of entry for V278 溝尾
# Found start of entry for V279 沁尾
# Found start of entry for V280 龍頭
# Found start of entry for V281 西埔
# Found start of entry for V282 上大阪
# Found start of entry for V283 下大坂
# Found start of entry for V284 磨坑里
# Found start of entry for V285 黄头埔
# Found start of entry for V286 坑北
# Found start of entry for V287 白塔
# Found start of entry for V288 刘厝
# Found start of entry for V289 营边
# Found start of entry for V290 菜厝
# Found start of entry for V291 歧厝
# Found start of entry for V292 东宋
# Found start of entry for V293 西亭
# Found start of entry for V294 凌厝
# Found start of entry for V295 下沟
# Found start of entry for V296 溝津洋
# Completed parsing A058 . 19 of 20 villages found
# parsing A059
# Found start of entry for V297 横塘
# Completed parsing A059 . 0 of 1 villages found
# parsing A060
# Found start of entry for V298 屿上
# Completed parsing A060 . 0 of 1 villages found
# parsing A061
# Found start of entry for V299 黄头
# Completed parsing A061 . 0 of 1 villages found
# parsing A062
# Found start of entry for V300 蔡宅
# Completed parsing A062 . 0 of 1 villages found
# parsing A063
# Found start of entry for V301 下林
# Completed parsing A063 . 0 of 1 villages found
# parsing A064
# Found start of entry for V302 东坡
# Completed parsing A064 . 0 of 1 villages found
# parsing A065
# Found start of entry for V303 下黄
# Found start of entry for V304 下度
# Found start of entry for V305 黄厝
# Found start of entry for V306 下埭尾
# Found start of entry for V307 上埭尾
# Found start of entry for V308 后墩
# Found start of entry for V309 社厝
# Found start of entry for V310 肖厝
# Found start of entry for V311 坂头
# Completed parsing A065 . 8 of 9 villages found
# parsing A066
# Found start of entry for V312 柳桥
# Found start of entry for V313 顶墩
# Found start of entry for V314 梧墩
# Completed parsing A066 . 2 of 3 villages found
# parsing A067
# Found start of entry for V315 沟头
# Completed parsing A067 . 0 of 1 villages found
# parsing A068
# Found start of entry for V316 筱塘
# Completed parsing A068 . 0 of 1 villages found
# parsing A069
# Found start of entry for V317 南门
# Completed parsing A069 . 0 of 1 villages found
# parsing A070
# Found start of entry for V318 北磨
# Found start of entry for V319 大溪
# Found start of entry for V320 下磨
# Found start of entry for V321 前埔
# Found start of entry for V322 下斜
# Completed parsing A070 . 4 of 5 villages found
# parsing A071
# Found start of entry for V323 安福
# Completed parsing A071 . 0 of 1 villages found
# parsing A072
# Found start of entry for V324 龙桥街
# Found start of entry for V325 顶龙桥
# Found start of entry for V326 下宫里
# Found start of entry for V327 土地后
# Found start of entry for V328 西山
# Found start of entry for V329 石顶
# Found start of entry for V330 老叶树
# Completed parsing A072 . 6 of 7 villages found
# parsing A073
# Found start of entry for V331 延寿
# Found start of entry for V332 欧徐尾
# Found start of entry for V333 下坡
# Found start of entry for V334 西头
# Found start of entry for V335 上林
# Found start of entry for V336 高井
# Completed parsing A073 . 5 of 6 villages found
# parsing A074
# Found start of entry for V337 隔沟
# Found start of entry for V338 辰门兜
# Found start of entry for V339 沟下
# Found start of entry for V340 义门
# Found start of entry for V341 西庚
# Found start of entry for V342 下戴
# Found start of entry for V343 潭头桥
# Completed parsing A074 . 6 of 7 villages found
# parsing A075
# Found start of entry for V344 东门兜
# Found start of entry for V345 梅花亭
# Found start of entry for V346 丰美
# Found start of entry for V347 西社
# Found start of entry for V348 莲塘
# Found start of entry for V349 下墩
# Completed parsing A075 . 5 of 6 villages found
# parsing A076
# Found start of entry for V350 阔口
# Found start of entry for V351 古山
# Completed parsing A076 . 1 of 2 villages found
# parsing A077
# Found start of entry for V352 后龚
# Found start of entry for V353 前浦
# Found start of entry for V354 社前
# Found start of entry for V355 郊西
# Completed parsing A077 . 3 of 4 villages found
# parsing A078
# Found start of entry for V356 黄墩
# Found start of entry for V357 郊东
# Found start of entry for V358 中社
# Found start of entry for V359 何社
# Completed parsing A078 . 3 of 4 villages found
# parsing A079
# Found start of entry for V360 浦南
# Completed parsing A079 . 1 of 4 villages found
# parsing A080
# Found start of entry for V364 草渚
# Completed parsing A080 . 0 of 1 villages found
# parsing A081
# Found start of entry for V365 南箕
# Found start of entry for V366 朱墩
# Found start of entry for V367 江边
# Found start of entry for V368 前布墩
# Found start of entry for V369 后布墩
# Completed parsing A081 . 4 of 5 villages found
# parsing A082
# Found start of entry for V370 西洙
# Found start of entry for V371 东阳
# Found start of entry for V372 沟西
# Found start of entry for V373 东埭
# Found start of entry for V374 徐桥
# Found start of entry for V375 西施
# Found start of entry for V376 梧塘
# Found start of entry for V377 沟美
# Completed parsing A082 . 7 of 8 villages found
# parsing A083
# Found start of entry for V378 畅山
# Found start of entry for V379 浦头
# Found start of entry for V380 大坝
# Found start of entry for V381 溪头
# Completed parsing A083 . 3 of 4 villages found
# parsing A084
# Found start of entry for V382 郊南
# Found start of entry for V383 郊北
# Found start of entry for V384 溪口
# Found start of entry for V385 下南郊
# Found start of entry for V386 西洋
# Found start of entry for V387 尾厝
# Found start of entry for V388 下厝
# Found start of entry for V389 衖里
# Found start of entry for V390 宫兜
# Completed parsing A084 . 8 of 9 villages found
# parsing A085
# Found start of entry for V391 下亭
# Found start of entry for V392 四亭
# Found start of entry for V393 郊下
# Found start of entry for V394 西漳
# Found start of entry for V395 西亭
# Completed parsing A085 . 4 of 5 villages found
# parsing A086
# Found start of entry for V396 前墩
# Found start of entry for V397 后墩
# Found start of entry for V398 辰南
# Found start of entry for V399 郊下里
# Completed parsing A086 . 3 of 4 villages found
# parsing A087
# Found start of entry for V400 陈桥
# Found start of entry for V401 后墩
# Found start of entry for V402 涵坝
# Found start of entry for V403 山步
# Completed parsing A087 . 3 of 4 villages found
# parsing A088
# Found start of entry for V404 梧郊
# Found start of entry for V405 蓝田
# Found start of entry for V406 牙口
# Completed parsing A088 . 2 of 3 villages found
# parsing A089
# Found start of entry for V407 上俞
# Found start of entry for V408 后亭
# Found start of entry for V409 岱埕
# Completed parsing A089 . 2 of 3 villages found
# parsing A090
# Found start of entry for V410 西湖
# Found start of entry for V411 度下
# Completed parsing A090 . 1 of 2 villages found
# parsing A091
# Found start of entry for V412 集奎
# Completed parsing A091 . 0 of 1 villages found
# parsing A092
# Found start of entry for V413 后宫
# Found start of entry for V414 后学
# Completed parsing A092 . 1 of 2 villages found
# parsing A093
# Found start of entry for V415 东亭
# Completed parsing A093 . 0 of 1 villages found
# parsing A094
# Found start of entry for V416 东墩
# Found start of entry for V417 李角
# Found start of entry for V418 西墩
# Found start of entry for V419 后头
# Found start of entry for V420 塘边
# Found start of entry for V421 西林
# Completed parsing A094 . 5 of 6 villages found
# parsing A095
# Found start of entry for V422 镇前
# Found start of entry for V423 镇江
# Found start of entry for V424 孝户
# Completed parsing A095 . 2 of 3 villages found
# parsing A096
# Found start of entry for V425 南埕
# Completed parsing A096 . 0 of 1 villages found
# parsing A097
# Found start of entry for V426 顶厝
# Found start of entry for V427 下郑
# Found start of entry for V428 孔里
# Completed parsing A097 . 2 of 3 villages found
# parsing A098
# Found start of entry for V429 洋西
# Found start of entry for V430 山兜
# Completed parsing A098 . 1 of 2 villages found
# parsing A099
# Found start of entry for V431 后墩
# Found start of entry for V432 下亭
# Found start of entry for V433 前墩
# Found start of entry for V434 上郭
# Found start of entry for V435 桃峰
# Completed parsing A099 . 4 of 5 villages found
# parsing A100
# Found start of entry for V436 白杜
# Found start of entry for V437 塘边
# Found start of entry for V438 隔垄
# Found start of entry for V439 路顶
# Found start of entry for V440 下溪
# Found start of entry for V441 下头
# Found start of entry for V442 企溪
# Found start of entry for V443 汉头
# Found start of entry for V444 古山
# Found start of entry for V445 东坂
# Completed parsing A100 . 9 of 10 villages found
# parsing A101
# Found start of entry for V446 洞湖
# Found start of entry for V447 西锅
# Found start of entry for V448 度西
# Completed parsing A101 . 2 of 3 villages found
# parsing A102
# Found start of entry for V449 后埔
# Found start of entry for V450 上黄
# Found start of entry for V451 林峰
# Found start of entry for V452 坑边
# Found start of entry for V453 坑头
# Found start of entry for V454 澄林
# Found start of entry for V455 下宇
# Found start of entry for V456 官塘
# Found start of entry for V457 西天尾
# Completed parsing A102 . 8 of 9 villages found
# parsing A103
# Found start of entry for V458 庙前
# Found start of entry for V459 俞里
# Found start of entry for V460 霞郑
# Found start of entry for V461 水流利
# Found start of entry for V462 半路店
# Found start of entry for V463 东黄
# Completed parsing A103 . 5 of 6 villages found
# parsing A104
# Found start of entry for V464 溪安
# Found start of entry for V465 大桥头
# Found start of entry for V466 后亭
# Found start of entry for V467 西山
# Found start of entry for V468 乌石
# Found start of entry for V469 北山
# Found start of entry for V470 新村
# Found start of entry for V471 圳下
# Completed parsing A104 . 7 of 8 villages found
# parsing A105
# Found start of entry for V472 陈墩
# Found start of entry for V473 后炉
# Found start of entry for V474 北郊
# Found start of entry for V475 郊下
# Found start of entry for V476 大沟
# Found start of entry for V477 西郑
# Completed parsing A105 . 5 of 6 villages found
# parsing A106
# Found start of entry for V478 上黄
# Completed parsing A106 . 0 of 1 villages found
# parsing A107
# Found start of entry for V479 朱衖
# Found start of entry for V480 郑墩
# Found start of entry for V481 柴桥头
# Found start of entry for V482 上林墩
# Found start of entry for V483 郊东
# Found start of entry for V484 郊西
# Found start of entry for V485 袍笏墩
# Completed parsing A107 . 6 of 7 villages found
# parsing A108
# Found start of entry for V486 吴江
# Completed parsing A108 . 0 of 1 villages found
# parsing A109
# Found start of entry for V487 上林
# Found start of entry for V488 下墩
# Found start of entry for V489 溪口
# Found start of entry for V490 游桥头
# Found start of entry for V491 蔡埭东至
# Found start of entry for V492 蔡埭西至
# Found start of entry for V493 前黄
# Found start of entry for V494 下澄
# Found start of entry for V495 下高
# Completed parsing A109 . 8 of 9 villages found
# parsing A110
# Found start of entry for V496 上郭
# Found start of entry for V497 前亭
# Found start of entry for V498 柯塘
# Completed parsing A110 . 2 of 3 villages found
# parsing A111
# Found start of entry for V499 魏塘
# Found start of entry for V500 郭庄
# Found start of entry for V501 东墩
# Found start of entry for V502 铺前
# Found start of entry for V503 西港
# Found start of entry for V504 庄厝
# Found start of entry for V505 洋池
# Found start of entry for V506 下洋
# Found start of entry for V507 后亭
# Found start of entry for V508 下宇
# Found start of entry for V508 下宇
# Completed parsing A111 . 9 of 10 villages found
# parsing A112
# Found start of entry for V509 北港
# Found start of entry for V510 周墩
# Found start of entry for V511 下江
# Found start of entry for V512 下枋
# Found start of entry for V513 加口
# Found start of entry for V514 田岑
# Completed parsing A112 . 5 of 6 villages found
# parsing A113
# Found start of entry for V515 利墩
# Found start of entry for V516 后郑
# Found start of entry for V517 新港
# Found start of entry for V518 大度下
# Found start of entry for V519 上郑
# Found start of entry for V520 江尾
# Found start of entry for V521 江边
# Completed parsing A113 . 6 of 7 villages found
# parsing A114
# Found start of entry for V522 美楼
# Found start of entry for V523 崇社
# Found start of entry for V524 外度下
# Found start of entry for V525 松柏戈
# Found start of entry for V526 柑园
# Completed parsing A114 . 4 of 5 villages found
# parsing A115
# Found start of entry for V527 南山
# Found start of entry for V528 洪度
# Found start of entry for V529 九坵
# Found start of entry for V530 下厝
# Found start of entry for V531 郭厝
# Found start of entry for V532 上后亭
# Found start of entry for V533 北埕
# Found start of entry for V534 东张
# Found start of entry for V535 田厝
# Completed parsing A115 . 8 of 9 villages found
# parsing A116
# Found start of entry for V536 邓厝
# Found start of entry for V537 牛山
# Found start of entry for V538 沁尾
# Found start of entry for V539 下田厝
# Completed parsing A116 . 3 of 4 villages found
# parsing A117
# Found start of entry for V540 渭阳
# Completed parsing A117 . 0 of 1 villages found
# parsing A118
# Found start of entry for V541 井头
# Found start of entry for V542 下柯
# Found start of entry for V543 山后
# Completed parsing A118 . 2 of 3 villages found
# parsing A119
# Found start of entry for V544 西洋
# Found start of entry for V545 后洋
# Found start of entry for V546 隔垄
# Found start of entry for V547 田厝
# Completed parsing A119 . 3 of 4 villages found
# parsing A120
# Found start of entry for V548 后黄
# Completed parsing A120 . 0 of 1 villages found
# parsing A121
# Found start of entry for V549 漏头
# Found start of entry for V550 方庄
# Completed parsing A121 . 1 of 2 villages found
# parsing A122
# Found start of entry for V551 林外
# Found start of entry for V552 梅岭
# Found start of entry for V553 西庄
# Found start of entry for V554 太白庄
# Found start of entry for V555 福兴社
# Found start of entry for V556 东牌
# Found start of entry for V557 霞楼
# Completed parsing A122 . 6 of 7 villages found
# parsing A123
# Found start of entry for V558 梧梓
# Completed parsing A123 . 0 of 1 villages found
# parsing A124
# Found start of entry for V559 道埔
# Found start of entry for V560 泗洲
# Found start of entry for V561 泗营
# Found start of entry for V562 肖甲
# Found start of entry for V563 直巷
# Found start of entry for V564 白园
# Found start of entry for V565 巷头
# Found start of entry for V566 岭前
# Found start of entry for V567 埔墩
# Found start of entry for V568 顶厝尾
# Found start of entry for V569 埔头
# Found start of entry for V570 西郑
# Completed parsing A124 . 11 of 12 villages found
# parsing A125
# Found start of entry for V571 联合村
# Found start of entry for V572 顶沟
# Found start of entry for V573 石牌兜
# Found start of entry for V574 田中央
# Completed parsing A125 . 3 of 4 villages found
# parsing A126
# Found start of entry for V575 码头
# Found start of entry for V576 都邠
# Found start of entry for V577 秀郊
# Found start of entry for V578 澄峰
# Found start of entry for V579 东坡
# Found start of entry for V580 南坑
# Completed parsing A126 . 5 of 6 villages found
# parsing A127
# Found start of entry for V581 霞肖
# Found start of entry for V582 黄巷
# Found start of entry for V583 下林
# Found start of entry for V584 苍口
# Found start of entry for V585 西林
# Found start of entry for V586 西坡
# Completed parsing A127 . 5 of 6 villages found
# parsing A128
# Found start of entry for V587 沁东
# Found start of entry for V588 沁西
# Found start of entry for V589 东徐
# Found start of entry for V590 南埔
# Completed parsing A128 . 4 of 10 villages found
# parsing A129
# Found start of entry for V597 喻坡
# Completed parsing A129 . 0 of 1 villages found
# parsing A130
# Found start of entry for V598 塘西
# Completed parsing A130 . 0 of 1 villages found
# parsing A131
# Completed parsing A131 . 0 of 1 villages found
# parsing A132
# Found start of entry for V600 楼下
# Found start of entry for V601 保尾
# Found start of entry for V602 塘北
# Found start of entry for V603 铺尾
# Found start of entry for V604 苍然
# Found start of entry for V605 延宁
# Found start of entry for V606 霞徐
# Found start of entry for V607 林墩
# Completed parsing A132 . 7 of 8 villages found
# parsing A133
# Found start of entry for V608 港头
# Found start of entry for V609 田尾
# Found start of entry for V610 前林
# Completed parsing A133 . 2 of 3 villages found
# parsing A134
# Found start of entry for V611 张公墩
# Found start of entry for V612 苏墩
# Found start of entry for V613 尾厝
# Found start of entry for V614 卢墩
# Found start of entry for V615 田中央
# Completed parsing A134 . 4 of 5 villages found
# parsing A135
# Found start of entry for V616 三股
# Found start of entry for V617 新坡
# Found start of entry for V618 巷利
# Found start of entry for V619 潭尾
# Found start of entry for V620 黄厝
# Found start of entry for V621 后洋
# Completed parsing A135 . 5 of 6 villages found
# parsing A136
# Found start of entry for V622 洞庭
# Found start of entry for V623 林柄
# Found start of entry for V624 埔尾
# Completed parsing A136 . 2 of 3 villages found
# parsing A137
# Found start of entry for V625 苏厝
# Found start of entry for V626 中墩
# Found start of entry for V627 金墩
# Found start of entry for V628 洋中
# Completed parsing A137 . 3 of 4 villages found
# parsing A138
# Completed parsing A138 . 0 of 1 villages found
# parsing A139
# Found start of entry for V630 温厝
# Found start of entry for V631 黄大庭
# Found start of entry for V632 刘安
# Completed parsing A139 . 2 of 3 villages found
# parsing A140
# Found start of entry for V633 后郭
# Found start of entry for V634 田头
# Found start of entry for V635 后董
# Completed parsing A140 . 2 of 3 villages found
# parsing A141
# Found start of entry for V636 后黄
# Found start of entry for V637 澳里
# Found start of entry for V638 下社
# Found start of entry for V639 下柯
# Found start of entry for V640 顶柯
# Found start of entry for V641 歧头
# Completed parsing A141 . 5 of 6 villages found
# parsing A142
# Found start of entry for V642 东埕
# Found start of entry for V643 石山
# Found start of entry for V644 新坡头
# Completed parsing A142 . 2 of 3 villages found
# parsing A143
# Found start of entry for V645 上梅
# Found start of entry for V646 后曾
# Found start of entry for V647 东曾
# Found start of entry for V648 西林
# Found start of entry for V649 东坊
# Found start of entry for V650 岭兜
# Completed parsing A143 . 5 of 6 villages found
# parsing A144
# Found start of entry for V651 哆前
# Found start of entry for V652 哆中
# Found start of entry for V653 哆后
# Completed parsing A144 . 2 of 3 villages found
# parsing A145
# Found start of entry for V654 凤秀
# Found start of entry for V655 半埕
# Found start of entry for V656 上方
# Found start of entry for V657 上港
# Found start of entry for V658 美尾
# Completed parsing A145 . 4 of 5 villages found
# parsing A146
# Completed parsing A146 . 0 of 1 villages found
# parsing A147
# Found start of entry for V660 孝义
# Found start of entry for V661 下后度
# Found start of entry for V662 劉井
# Found start of entry for V663 前會
# Found start of entry for V664 度围头
# Found start of entry for V665 港下
# Found start of entry for V666 后墩
# Found start of entry for V667 新井
# Completed parsing A147 . 7 of 8 villages found
# parsing A148
# Found start of entry for V668 前王
# Found start of entry for V669 石灰
# Found start of entry for V670 山头
# Found start of entry for V671 油岚
# Found start of entry for V672 石狮
# Completed parsing A148 . 4 of 5 villages found
# parsing A149
# Found start of entry for V673 沟上
# Found start of entry for V674 蔗车
# Found start of entry for V675 李厝
# Found start of entry for V676 新店
# Found start of entry for V677 新墩
# Found start of entry for V678 后埕埔
# Found start of entry for V679 前面
# Found start of entry for V680 顶墩
# Found start of entry for V681 下墩
# Found start of entry for V682 吴墩
# Found start of entry for V683 游墩
# Completed parsing A149 . 10 of 11 villages found
# parsing A150
# Found start of entry for V684 上林
# Found start of entry for V685 东施
# Found start of entry for V686 埔埕
# Found start of entry for V687 西刘
# Found start of entry for V688 东蔡
# Found start of entry for V689 界下
# Completed parsing A150 . 5 of 6 villages found
# parsing A151
# Found start of entry for V690 后亭
# Found start of entry for V691 吴墩洋
# Found start of entry for V692 顶旧厝
# Found start of entry for V693 旗杆厝
# Found start of entry for V694 小郊尾
# Found start of entry for V695 铁灶
# Found start of entry for V696 田中央
# Completed parsing A151 . 7 of 16 villages found
# parsing A152
# Found start of entry for V706 下肖
# Found start of entry for V707 下邦尾
# Found start of entry for V708 顶邦尾
# Completed parsing A152 . 3 of 6 villages found
